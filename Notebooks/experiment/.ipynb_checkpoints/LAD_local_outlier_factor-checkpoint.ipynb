# %% [markdown]
# ### Log Anomlay Detector Core Mininimal Implementation
#
# In an effort to help new users and contributors understand the core Machine Learning elements of the log anomaly detector I have decided to recreate a streamlined minimal version. Here we will ignore any streaming or external aspect of our data and use a fixed local data file for simplicity and reproducability.
#
# This notebook will cover:
# * Log Preprocessing
# * Text Encoding
# * Model Training
# * Generating Anomlay Scores
# * Model Inference /Prediction
#
# For the most part function names have been made to match their relevent counter part in the larger code base.
#
# My aim for this notebook is that, by the end a reader will 1) have a clear understanding of how the current implementation works and 2) know where to make changes to try another approach.

# %% [markdown]
# ### Import our packages

# %%
import os
import time
import numpy as np
import logging
import sompy



from multiprocessing import Pool
from itertools import product
import pandas as pd
import re
import gensim as gs
import matplotlib.pyplot as plt
from scipy.spatial.distance import cosine
from sklearn.preprocessing import normalize

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# CACHEDIR=/home/nadzya/.cache/matplotlib
# Using fontManager instance from /home/nadzya/.cache/matplotlib/fontlist-v330.json
# Loaded backend module://ipykernel.pylab.backend_inline version unknown.
# Loaded backend module://ipykernel.pylab.backend_inline version unknown.
# NumExpr defaulting to 4 threads.
# Loaded backend module://matplotlib_inline.backend_inline version unknown.

# %% [markdown]
# ### Define our Functions
#
# #### 1. Log Preprocesing
#
# One assumption that all these functions use is that we instantly convert our data into a pandas dataframe that has a "message" column containing the relevent information for us.
#
# We then treat each individual log line as a "word", cleaning it by removing all non-alphabet charcters including white spaces.

# %%
def _preprocess(data):
    for col in data.columns:
        if col == "message":
            data[col] = data[col].apply(_clean_message)
        else:
            data[col] = data[col].apply(to_str)

    data = data.fillna("EMPTY")
    
def _clean_message(line):
    """Remove all none alphabetical characters from message strings."""
    return "".join(
        re.findall("[a-zA-Z]+", line)
    )  # Leaving only a-z in there as numbers add to anomalousness quite a bit

def to_str(x):
    """Convert all non-str lists to string lists for Word2Vec."""
    ret = " ".join([str(y) for y in x]) if isinstance(x, list) else str(x)
    return ret

# %% [markdown]
# #### 2. Text Encoding
#
# Here we employ the gensim implementation of Word2Vec to encode our logs as fixed length numerical vectors. Logs are noteably not the natural usecase for word2vec, but this appraoch attemps to leverage the fact that logs lines themselves, like words, have a context, so encoding a log based on its co-occurence with other logs does make some intuitive sense.

# %%
def create(words, vector_length, window_size):
    """Create new word2vec model."""
    w2vmodel = {}
    for col in words.columns:
        if col in words:
            w2vmodel[col] = gs.models.Word2Vec([list(words[col])], min_count=1, size=vector_length, 
                                     window=window_size, seed=42, workers=1, iter=550,sg=0)
        else:
            #_LOGGER.warning("Skipping key %s as it does not exist in 'words'" % col)
            pass
        
    return w2vmodel

def one_vector(new_D, w2vmodel):
    """Create a single vector from model."""
    transforms = {}
    for col in w2vmodel.keys():
        if col in new_D:
            transforms[col] = w2vmodel[col].wv[new_D[col]]

    new_data = []

    for i in range(len(transforms["message"])):
        logc = np.array(0)
        for _, c in transforms.items():
            if c.item(i):
                logc = np.append(logc, c[i])
            else:
                logc = np.append(logc, [0, 0, 0, 0, 0])
        new_data.append(logc)

    return np.array(new_data, ndmin=2)

# %% [markdown]
# #### 3. Model Training
#
# Here we employ the SOMPY implementation of the Self-Organizing Map to train our model. This function simply makes it a bit easier for the user to interact with the sompy training requirements. This function returns a trained model.
#
# The trained model object also has a method called codebook.matrix() which allows the user access directly to the trained self organizing map itself. If the map successfull converged then it should consist of nodes in our N-dimensional log space that are well ordered and provide an approximation to the topology of the logs in our training set.
#
# During training we also, compute the distances of our training data to the trained map as a baseline to build a threashold.

# %%
def train(inp, map_size, iterations, parallelism):
    print('training dataset is of size {inp.shape[0]}')
    mapsize = [map_size, map_size]
    np.random.seed(42)
    som = sompy.SOMFactory.build(inp, mapsize , initialization='random')
    som.train(n_job=parallelism, train_rough_len=100,train_finetune_len=5)
    model = som.codebook.matrix.reshape([map_size, map_size, inp.shape[1]])
    
    #distances = get_anomaly_score(inp, 8, model)
    #threshold = 3*np.std(distances) + np.mean(distances)
    
    return som #,threshold

# %% [markdown]
# #### 4. Generating Anomaly Scores
#
# One of the key elements of this approach is quantifying the distance between our logs and the nodes on our self organizing map. The two functions below, taken together, represent a parrallel implementation for performing this calculaton.

# %%
def get_anomaly_score(logs, parallelism, model): # for whole dataset 

    parameters = [[x,model] for x in logs]
    pool = Pool(parallelism)
    dist = pool.map(calculate_anomaly_score, parameters) 
    pool.close()
    pool.join()
    #dist = [] 
    #for log in logs:
    #    dist.append(calculate_anomaly_score(log,model))
    
    return dist

def calculate_anomaly_score(parameters): # for a data point 
    log = parameters[0]
    model = parameters[1]
    """Compute a distance of a log entry to elements of SOM."""
    dist_smallest = np.inf
    for x in range(model.shape[0]):
        for y in range(model.shape[1]):
            dist = cosine(model[x][y],log) 
            #dist = np.linalg.norm(model[x][y] - log)
            if dist < dist_smallest:
                dist_smallest = dist
    return dist_smallest

# %% [markdown]
# #### 5. Model Inference / Prediction
#
# Here we are making an inference about a new log message. This is done by scoring the incoming log and evaluating whether or not it passess a certain threshold value.
#
#
# Ideally our word2vec has been monitoring our application long enough to have seen all the logs. So, if we get a known log we can simply look up its vector representation
#
# One downside with word2vec is that its quite brittle when it comes to incorporating words that haven't been seen before. In this example, we will retrain the W2Vmodel if our new log has not been seen by the before.

# %%
def infer(w2v, som, log, data, threshold):
    
    log =  pd.DataFrame({"message":log},index=[1])
    _preprocess(log)
    
    if log.message.iloc[0] in list(w2v['message'].wv.vocab.keys()):
        vector = w2v["message"].wv[log.message.iloc[0]]
    else:
        w2v = gs.models.Word2Vec([[log.message.iloc[0]] + list(data["message"])], 
                                 min_count=1, size=100, window=3, seed=42, workers=1, iter=550, sg=0)
        vector = w2v.wv[log.message.iloc[0]]
    
    score = get_anomaly_score([vector], 1, som)
    
    if score < threshold:
        return 0, score
    else:
        return 1, score

# %% [markdown]
# ### Implementation
#
# First we read in our test dataset and preprocesses. Here was can see this is a rather small example, with 10,000 log lines, but only 3 unique log messages

# %%
data_path = "/home/nadzya/Apps/log-anomaly-detector/validation_data//log_anomaly_detector-10000-events.json"

# %%
data = pd.read_json(data_path)

# %%
_preprocess(data)
data.head()
# Out:
#                        message
# 0  DEBUGProcessedoutofpackages
# 1  DEBUGProcessedoutofpackages
# 2  DEBUGProcessedoutofpackages
# 3  DEBUGProcessedoutofpackages
# 4  DEBUGProcessedoutofpackages

# %%
data.tail()
# Out:
#                           message
# 9995  DEBUGProcessedoutofpackages
# 9996  DEBUGProcessedoutofpackages
# 9997  DEBUGProcessedoutofpackages
# 9998  DEBUGProcessedoutofpackages
# 9999  DEBUGProcessedoutofpackages

# %%
x = data.message.value_counts()
for i in x.keys():
    print(i, x[i])
# Out:
# DEBUGProcessedoutofpackages 9786
# ThreadodcsserverINFOComposetypestatedoneComposedone 213
# rootCMDusrlocalbinmonitorapachestatsshdevnull 1

# %% [markdown]
# #### Encode our logs
#
# We then create our w2vmodel based on our preprocessed dataset and replace our log lines with thier vectorized representation.

# %%
w2vmodel = create(data, 100,3)
# Out:
# collecting all words and their counts
# PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# collected 3 word types from a corpus of 10000 raw words and 1 sentences
# Loading a fresh vocabulary
# effective_min_count=1 retains 3 unique words (100% of original 3, drops 0)
# effective_min_count=1 leaves 10000 word corpus (100% of original 10000, drops 0)
# deleting the raw counts dictionary of 3 items
# sample=0.001 downsamples 2 most-common words
# downsampling leaves estimated 379 word corpus (3.8% of prior 10000)
# estimated required memory for 3 words and 100 dimensions: 3900 bytes
# resetting layer weights
# training model with 1 workers on 3 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=3
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 1 : training on 10000 raw words (377 effective words) took 0.0s, 107674 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 2 : training on 10000 raw words (371 effective words) took 0.0s, 144169 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 3 : training on 10000 raw words (364 effective words) took 0.0s, 57632 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 4 : training on 10000 raw words (404 effective words) took 0.0s, 104993 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 5 : training on 10000 raw words (379 effective words) took 0.0s, 35960 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 6 : training on 10000 raw words (435 effective words) took 0.0s, 38794 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 7 : training on 10000 raw words (369 effective words) took 0.0s, 143354 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 8 : training on 10000 raw words (412 effective words) took 0.0s, 89250 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 9 : training on 10000 raw words (361 effective words) took 0.0s, 85939 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 10 : training on 10000 raw words (363 effective words) took 0.0s, 91618 effective words/s
# job loop exiting, total 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 11 : training on 10000 raw words (416 effective words) took 0.0s, 61208 effective words/s
# worker exiting, processed 1 jobs
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 12 : training on 10000 raw words (381 effective words) took 0.0s, 49923 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 13 : training on 10000 raw words (327 effective words) took 0.0s, 20726 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 14 : training on 10000 raw words (365 effective words) took 0.0s, 73462 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 15 : training on 10000 raw words (386 effective words) took 0.0s, 103062 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 16 : training on 10000 raw words (384 effective words) took 0.0s, 46741 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 17 : training on 10000 raw words (348 effective words) took 0.0s, 75318 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 18 : training on 10000 raw words (364 effective words) took 0.0s, 116542 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 19 : training on 10000 raw words (394 effective words) took 0.0s, 26831 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 20 : training on 10000 raw words (416 effective words) took 0.0s, 189616 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 21 : training on 10000 raw words (409 effective words) took 0.0s, 45038 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 22 : training on 10000 raw words (394 effective words) took 0.0s, 60225 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 23 : training on 10000 raw words (367 effective words) took 0.0s, 68986 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 24 : training on 10000 raw words (382 effective words) took 0.0s, 28511 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 25 : training on 10000 raw words (361 effective words) took 0.0s, 64998 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 26 : training on 10000 raw words (370 effective words) took 0.0s, 90157 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 27 : training on 10000 raw words (383 effective words) took 0.0s, 92093 effective words/s
# job loop exiting, total 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 28 : training on 10000 raw words (407 effective words) took 0.0s, 55975 effective words/s
# worker exiting, processed 1 jobs
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 29 : training on 10000 raw words (390 effective words) took 0.0s, 78218 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 30 : training on 10000 raw words (380 effective words) took 0.0s, 63625 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 31 : training on 10000 raw words (364 effective words) took 0.0s, 38953 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 32 : training on 10000 raw words (380 effective words) took 0.0s, 35600 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 33 : training on 10000 raw words (378 effective words) took 0.0s, 76922 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 34 : training on 10000 raw words (410 effective words) took 0.0s, 93748 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 35 : training on 10000 raw words (366 effective words) took 0.0s, 53685 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 36 : training on 10000 raw words (354 effective words) took 0.0s, 107307 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 37 : training on 10000 raw words (381 effective words) took 0.0s, 87357 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 38 : training on 10000 raw words (378 effective words) took 0.0s, 81841 effective words/s
# job loop exiting, total 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 39 : training on 10000 raw words (355 effective words) took 0.0s, 59307 effective words/s
# worker exiting, processed 1 jobs
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 40 : training on 10000 raw words (394 effective words) took 0.0s, 42195 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 41 : training on 10000 raw words (388 effective words) took 0.0s, 63002 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 42 : training on 10000 raw words (396 effective words) took 0.0s, 88547 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 43 : training on 10000 raw words (407 effective words) took 0.0s, 61919 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 44 : training on 10000 raw words (379 effective words) took 0.0s, 92369 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 45 : training on 10000 raw words (383 effective words) took 0.0s, 42082 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 46 : training on 10000 raw words (388 effective words) took 0.0s, 49648 effective words/s
# job loop exiting, total 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# worker exiting, processed 1 jobs
# EPOCH - 47 : training on 10000 raw words (386 effective words) took 0.0s, 117981 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 48 : training on 10000 raw words (396 effective words) took 0.0s, 86515 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 49 : training on 10000 raw words (349 effective words) took 0.0s, 135575 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 50 : training on 10000 raw words (370 effective words) took 0.0s, 81758 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 51 : training on 10000 raw words (377 effective words) took 0.0s, 89544 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 52 : training on 10000 raw words (403 effective words) took 0.0s, 32259 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 53 : training on 10000 raw words (361 effective words) took 0.0s, 128493 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 54 : training on 10000 raw words (386 effective words) took 0.0s, 67567 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 55 : training on 10000 raw words (364 effective words) took 0.0s, 132531 effective words/s
# job loop exiting, total 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# worker exiting, processed 1 jobs
# EPOCH - 56 : training on 10000 raw words (363 effective words) took 0.0s, 116170 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 57 : training on 10000 raw words (361 effective words) took 0.0s, 47396 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 58 : training on 10000 raw words (352 effective words) took 0.0s, 43710 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 59 : training on 10000 raw words (403 effective words) took 0.0s, 83616 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 60 : training on 10000 raw words (355 effective words) took 0.0s, 79713 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 61 : training on 10000 raw words (402 effective words) took 0.0s, 90914 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 62 : training on 10000 raw words (402 effective words) took 0.0s, 50926 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 63 : training on 10000 raw words (393 effective words) took 0.0s, 148051 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 64 : training on 10000 raw words (366 effective words) took 0.0s, 84104 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 65 : training on 10000 raw words (372 effective words) took 0.0s, 46163 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 66 : training on 10000 raw words (405 effective words) took 0.0s, 91983 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 67 : training on 10000 raw words (362 effective words) took 0.0s, 45111 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 68 : training on 10000 raw words (380 effective words) took 0.0s, 97611 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 69 : training on 10000 raw words (416 effective words) took 0.0s, 63294 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 70 : training on 10000 raw words (371 effective words) took 0.0s, 130900 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 71 : training on 10000 raw words (355 effective words) took 0.0s, 74419 effective words/s
# job loop exiting, total 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# worker exiting, processed 1 jobs
# EPOCH - 72 : training on 10000 raw words (376 effective words) took 0.0s, 90992 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 73 : training on 10000 raw words (395 effective words) took 0.0s, 63105 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 74 : training on 10000 raw words (349 effective words) took 0.0s, 86838 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 75 : training on 10000 raw words (381 effective words) took 0.0s, 23214 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 76 : training on 10000 raw words (366 effective words) took 0.0s, 59869 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 77 : training on 10000 raw words (379 effective words) took 0.0s, 61704 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 78 : training on 10000 raw words (372 effective words) took 0.0s, 46728 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 79 : training on 10000 raw words (347 effective words) took 0.0s, 99298 effective words/s
# job loop exiting, total 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# worker exiting, processed 1 jobs
# EPOCH - 80 : training on 10000 raw words (366 effective words) took 0.0s, 123910 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 81 : training on 10000 raw words (359 effective words) took 0.0s, 41864 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 82 : training on 10000 raw words (362 effective words) took 0.0s, 53188 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 83 : training on 10000 raw words (387 effective words) took 0.0s, 85454 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 84 : training on 10000 raw words (369 effective words) took 0.0s, 77666 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 85 : training on 10000 raw words (367 effective words) took 0.0s, 69211 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 86 : training on 10000 raw words (400 effective words) took 0.0s, 55287 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 87 : training on 10000 raw words (428 effective words) took 0.0s, 164986 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 88 : training on 10000 raw words (378 effective words) took 0.0s, 116461 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 89 : training on 10000 raw words (394 effective words) took 0.0s, 70846 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 90 : training on 10000 raw words (398 effective words) took 0.0s, 19808 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 91 : training on 10000 raw words (369 effective words) took 0.0s, 24594 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 92 : training on 10000 raw words (369 effective words) took 0.0s, 96414 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 93 : training on 10000 raw words (385 effective words) took 0.0s, 60227 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 94 : training on 10000 raw words (343 effective words) took 0.0s, 68624 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 95 : training on 10000 raw words (387 effective words) took 0.0s, 49145 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 96 : training on 10000 raw words (354 effective words) took 0.0s, 64957 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 97 : training on 10000 raw words (368 effective words) took 0.0s, 41208 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 98 : training on 10000 raw words (398 effective words) took 0.0s, 68058 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 99 : training on 10000 raw words (393 effective words) took 0.0s, 32166 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 100 : training on 10000 raw words (378 effective words) took 0.0s, 61077 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 101 : training on 10000 raw words (362 effective words) took 0.0s, 39056 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 102 : training on 10000 raw words (387 effective words) took 0.0s, 42891 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 103 : training on 10000 raw words (383 effective words) took 0.0s, 64465 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 104 : training on 10000 raw words (403 effective words) took 0.0s, 136417 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 105 : training on 10000 raw words (368 effective words) took 0.0s, 47701 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 106 : training on 10000 raw words (380 effective words) took 0.0s, 61859 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 107 : training on 10000 raw words (388 effective words) took 0.0s, 54317 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 108 : training on 10000 raw words (373 effective words) took 0.0s, 34955 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 109 : training on 10000 raw words (354 effective words) took 0.0s, 100446 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 110 : training on 10000 raw words (403 effective words) took 0.0s, 36671 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 111 : training on 10000 raw words (384 effective words) took 0.0s, 66946 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 112 : training on 10000 raw words (365 effective words) took 0.0s, 58874 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 113 : training on 10000 raw words (400 effective words) took 0.0s, 56930 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 114 : training on 10000 raw words (395 effective words) took 0.0s, 129665 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 115 : training on 10000 raw words (416 effective words) took 0.0s, 109610 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 116 : training on 10000 raw words (371 effective words) took 0.0s, 88255 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 117 : training on 10000 raw words (365 effective words) took 0.0s, 86945 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 118 : training on 10000 raw words (367 effective words) took 0.0s, 71690 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 119 : training on 10000 raw words (335 effective words) took 0.0s, 95224 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 120 : training on 10000 raw words (376 effective words) took 0.0s, 66675 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 121 : training on 10000 raw words (385 effective words) took 0.0s, 65715 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 122 : training on 10000 raw words (383 effective words) took 0.0s, 60023 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 123 : training on 10000 raw words (409 effective words) took 0.0s, 33694 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 124 : training on 10000 raw words (413 effective words) took 0.0s, 82133 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 125 : training on 10000 raw words (427 effective words) took 0.0s, 45855 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 126 : training on 10000 raw words (367 effective words) took 0.0s, 45083 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 127 : training on 10000 raw words (364 effective words) took 0.0s, 38126 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 128 : training on 10000 raw words (401 effective words) took 0.0s, 87900 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 129 : training on 10000 raw words (363 effective words) took 0.0s, 95389 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 130 : training on 10000 raw words (373 effective words) took 0.0s, 84468 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 131 : training on 10000 raw words (360 effective words) took 0.0s, 46203 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 132 : training on 10000 raw words (393 effective words) took 0.0s, 73102 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 133 : training on 10000 raw words (329 effective words) took 0.0s, 79366 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 134 : training on 10000 raw words (409 effective words) took 0.0s, 74127 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 135 : training on 10000 raw words (382 effective words) took 0.0s, 41695 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 136 : training on 10000 raw words (381 effective words) took 0.0s, 88107 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 137 : training on 10000 raw words (388 effective words) took 0.0s, 97720 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 138 : training on 10000 raw words (402 effective words) took 0.0s, 48163 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 139 : training on 10000 raw words (391 effective words) took 0.0s, 48482 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 140 : training on 10000 raw words (349 effective words) took 0.0s, 44039 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 141 : training on 10000 raw words (412 effective words) took 0.0s, 100522 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 142 : training on 10000 raw words (365 effective words) took 0.0s, 79411 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 143 : training on 10000 raw words (392 effective words) took 0.0s, 34234 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 144 : training on 10000 raw words (361 effective words) took 0.0s, 40814 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 145 : training on 10000 raw words (393 effective words) took 0.0s, 126394 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 146 : training on 10000 raw words (372 effective words) took 0.0s, 78479 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 147 : training on 10000 raw words (401 effective words) took 0.0s, 57792 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 148 : training on 10000 raw words (364 effective words) took 0.0s, 46037 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 149 : training on 10000 raw words (361 effective words) took 0.0s, 84959 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 150 : training on 10000 raw words (400 effective words) took 0.0s, 74753 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 151 : training on 10000 raw words (365 effective words) took 0.0s, 74990 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 152 : training on 10000 raw words (400 effective words) took 0.0s, 51126 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 153 : training on 10000 raw words (398 effective words) took 0.0s, 96048 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 154 : training on 10000 raw words (371 effective words) took 0.0s, 100456 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 155 : training on 10000 raw words (379 effective words) took 0.0s, 60886 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 156 : training on 10000 raw words (382 effective words) took 0.0s, 55913 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 157 : training on 10000 raw words (354 effective words) took 0.0s, 84883 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 158 : training on 10000 raw words (386 effective words) took 0.0s, 90469 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 159 : training on 10000 raw words (351 effective words) took 0.0s, 58516 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 160 : training on 10000 raw words (368 effective words) took 0.0s, 93530 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 161 : training on 10000 raw words (379 effective words) took 0.0s, 78719 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 162 : training on 10000 raw words (338 effective words) took 0.0s, 69680 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 163 : training on 10000 raw words (384 effective words) took 0.0s, 46972 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 164 : training on 10000 raw words (377 effective words) took 0.0s, 82351 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 165 : training on 10000 raw words (387 effective words) took 0.0s, 84941 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 166 : training on 10000 raw words (363 effective words) took 0.0s, 69490 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 167 : training on 10000 raw words (367 effective words) took 0.0s, 134518 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 168 : training on 10000 raw words (380 effective words) took 0.0s, 74628 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 169 : training on 10000 raw words (353 effective words) took 0.0s, 66153 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 170 : training on 10000 raw words (399 effective words) took 0.0s, 81494 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 171 : training on 10000 raw words (379 effective words) took 0.0s, 92160 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 172 : training on 10000 raw words (386 effective words) took 0.0s, 65291 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 173 : training on 10000 raw words (383 effective words) took 0.0s, 150821 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 174 : training on 10000 raw words (406 effective words) took 0.0s, 85437 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 175 : training on 10000 raw words (374 effective words) took 0.0s, 80636 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 176 : training on 10000 raw words (387 effective words) took 0.0s, 43804 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 177 : training on 10000 raw words (360 effective words) took 0.0s, 59136 effective words/s
# job loop exiting, total 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# worker exiting, processed 1 jobs
# EPOCH - 178 : training on 10000 raw words (356 effective words) took 0.0s, 98966 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 179 : training on 10000 raw words (368 effective words) took 0.0s, 89459 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 180 : training on 10000 raw words (395 effective words) took 0.0s, 54521 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 181 : training on 10000 raw words (408 effective words) took 0.0s, 85592 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 182 : training on 10000 raw words (380 effective words) took 0.0s, 82965 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 183 : training on 10000 raw words (399 effective words) took 0.0s, 62065 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 184 : training on 10000 raw words (378 effective words) took 0.0s, 44141 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 185 : training on 10000 raw words (383 effective words) took 0.0s, 97093 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 186 : training on 10000 raw words (416 effective words) took 0.0s, 52857 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 187 : training on 10000 raw words (373 effective words) took 0.0s, 83599 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 188 : training on 10000 raw words (391 effective words) took 0.0s, 55134 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 189 : training on 10000 raw words (384 effective words) took 0.0s, 94773 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 190 : training on 10000 raw words (350 effective words) took 0.0s, 79313 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 191 : training on 10000 raw words (384 effective words) took 0.0s, 77517 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 192 : training on 10000 raw words (328 effective words) took 0.0s, 41765 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 193 : training on 10000 raw words (368 effective words) took 0.0s, 130312 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 194 : training on 10000 raw words (390 effective words) took 0.0s, 93465 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 195 : training on 10000 raw words (408 effective words) took 0.0s, 93985 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 196 : training on 10000 raw words (382 effective words) took 0.0s, 51786 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 197 : training on 10000 raw words (377 effective words) took 0.0s, 178867 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 198 : training on 10000 raw words (399 effective words) took 0.0s, 72202 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 199 : training on 10000 raw words (395 effective words) took 0.0s, 24316 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 200 : training on 10000 raw words (362 effective words) took 0.0s, 42743 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 201 : training on 10000 raw words (391 effective words) took 0.0s, 95851 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 202 : training on 10000 raw words (389 effective words) took 0.0s, 77445 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 203 : training on 10000 raw words (382 effective words) took 0.0s, 47691 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 204 : training on 10000 raw words (342 effective words) took 0.0s, 48234 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 205 : training on 10000 raw words (382 effective words) took 0.0s, 48969 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 206 : training on 10000 raw words (373 effective words) took 0.0s, 89453 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 207 : training on 10000 raw words (391 effective words) took 0.0s, 53390 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 208 : training on 10000 raw words (373 effective words) took 0.0s, 59264 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 209 : training on 10000 raw words (381 effective words) took 0.0s, 58558 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 210 : training on 10000 raw words (385 effective words) took 0.0s, 25994 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 211 : training on 10000 raw words (361 effective words) took 0.0s, 33317 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 212 : training on 10000 raw words (328 effective words) took 0.0s, 89469 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 213 : training on 10000 raw words (377 effective words) took 0.0s, 35282 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 214 : training on 10000 raw words (402 effective words) took 0.0s, 44062 effective words/s
# job loop exiting, total 1 jobs
# ...
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 479 : training on 10000 raw words (354 effective words) took 0.0s, 49749 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 480 : training on 10000 raw words (413 effective words) took 0.0s, 55532 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 481 : training on 10000 raw words (371 effective words) took 0.0s, 146934 effective words/s
# job loop exiting, total 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 482 : training on 10000 raw words (370 effective words) took 0.0s, 137540 effective words/s
# worker exiting, processed 1 jobs
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 483 : training on 10000 raw words (387 effective words) took 0.0s, 37492 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 484 : training on 10000 raw words (412 effective words) took 0.0s, 70435 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 485 : training on 10000 raw words (387 effective words) took 0.0s, 100929 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 486 : training on 10000 raw words (377 effective words) took 0.0s, 38979 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 487 : training on 10000 raw words (360 effective words) took 0.0s, 75477 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 488 : training on 10000 raw words (404 effective words) took 0.0s, 31752 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 489 : training on 10000 raw words (354 effective words) took 0.0s, 63228 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 490 : training on 10000 raw words (407 effective words) took 0.0s, 56274 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 491 : training on 10000 raw words (393 effective words) took 0.0s, 50584 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 492 : training on 10000 raw words (375 effective words) took 0.0s, 60341 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 493 : training on 10000 raw words (380 effective words) took 0.0s, 104561 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 494 : training on 10000 raw words (394 effective words) took 0.0s, 77839 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 495 : training on 10000 raw words (381 effective words) took 0.0s, 45563 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 496 : training on 10000 raw words (361 effective words) took 0.0s, 51674 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 497 : training on 10000 raw words (372 effective words) took 0.0s, 83740 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 498 : training on 10000 raw words (380 effective words) took 0.0s, 59818 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 499 : training on 10000 raw words (369 effective words) took 0.0s, 49819 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 500 : training on 10000 raw words (381 effective words) took 0.0s, 44283 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 501 : training on 10000 raw words (385 effective words) took 0.0s, 98205 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 502 : training on 10000 raw words (384 effective words) took 0.0s, 64835 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 503 : training on 10000 raw words (349 effective words) took 0.0s, 89238 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 504 : training on 10000 raw words (372 effective words) took 0.0s, 59894 effective words/s
# job loop exiting, total 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# worker exiting, processed 1 jobs
# EPOCH - 505 : training on 10000 raw words (372 effective words) took 0.0s, 85749 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 506 : training on 10000 raw words (382 effective words) took 0.0s, 28936 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 507 : training on 10000 raw words (392 effective words) took 0.0s, 54266 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 508 : training on 10000 raw words (396 effective words) took 0.0s, 79136 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 509 : training on 10000 raw words (371 effective words) took 0.0s, 60550 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 510 : training on 10000 raw words (378 effective words) took 0.0s, 60308 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 511 : training on 10000 raw words (390 effective words) took 0.0s, 43539 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 512 : training on 10000 raw words (353 effective words) took 0.0s, 61041 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 513 : training on 10000 raw words (382 effective words) took 0.0s, 81467 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 514 : training on 10000 raw words (368 effective words) took 0.0s, 73941 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 515 : training on 10000 raw words (394 effective words) took 0.0s, 43292 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 516 : training on 10000 raw words (364 effective words) took 0.0s, 52427 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 517 : training on 10000 raw words (397 effective words) took 0.0s, 87698 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 518 : training on 10000 raw words (397 effective words) took 0.0s, 67780 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 519 : training on 10000 raw words (381 effective words) took 0.0s, 30873 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 520 : training on 10000 raw words (351 effective words) took 0.0s, 41193 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 521 : training on 10000 raw words (369 effective words) took 0.0s, 161138 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 522 : training on 10000 raw words (398 effective words) took 0.0s, 51778 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 523 : training on 10000 raw words (363 effective words) took 0.0s, 123594 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 524 : training on 10000 raw words (392 effective words) took 0.0s, 35690 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 525 : training on 10000 raw words (360 effective words) took 0.0s, 65502 effective words/s
# job loop exiting, total 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 526 : training on 10000 raw words (389 effective words) took 0.0s, 47451 effective words/s
# worker exiting, processed 1 jobs
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 527 : training on 10000 raw words (353 effective words) took 0.0s, 46628 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 528 : training on 10000 raw words (353 effective words) took 0.0s, 70434 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 529 : training on 10000 raw words (394 effective words) took 0.0s, 92586 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 530 : training on 10000 raw words (386 effective words) took 0.0s, 76118 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 531 : training on 10000 raw words (391 effective words) took 0.0s, 51055 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 532 : training on 10000 raw words (382 effective words) took 0.0s, 89383 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 533 : training on 10000 raw words (391 effective words) took 0.0s, 67593 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 534 : training on 10000 raw words (370 effective words) took 0.0s, 126372 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 535 : training on 10000 raw words (394 effective words) took 0.0s, 82723 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 536 : training on 10000 raw words (379 effective words) took 0.0s, 161953 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 537 : training on 10000 raw words (374 effective words) took 0.0s, 65877 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 538 : training on 10000 raw words (397 effective words) took 0.0s, 28182 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 539 : training on 10000 raw words (388 effective words) took 0.0s, 66866 effective words/s
# job loop exiting, total 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# worker exiting, processed 1 jobs
# EPOCH - 540 : training on 10000 raw words (350 effective words) took 0.0s, 105653 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 541 : training on 10000 raw words (366 effective words) took 0.0s, 146491 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 542 : training on 10000 raw words (372 effective words) took 0.0s, 82271 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 543 : training on 10000 raw words (379 effective words) took 0.0s, 82461 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 544 : training on 10000 raw words (408 effective words) took 0.0s, 89313 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 545 : training on 10000 raw words (376 effective words) took 0.0s, 179436 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 546 : training on 10000 raw words (385 effective words) took 0.0s, 60890 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 547 : training on 10000 raw words (363 effective words) took 0.0s, 128382 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 548 : training on 10000 raw words (394 effective words) took 0.0s, 40497 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 549 : training on 10000 raw words (350 effective words) took 0.0s, 60283 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 550 : training on 10000 raw words (400 effective words) took 0.0s, 78979 effective words/s
# training on a 5500000 raw words (209005 effective words) took 5.5s, 37803 effective words/s

# %%
transformed_data = one_vector(data, w2vmodel)
transformed_data = transformed_data[:,1:]

# %% [markdown]
# # Implement Local Outlier Factor
#
# Use preprocessed data in local outlier factor model to classify anomaly logs.
# Local outlier factor is a density-based method that relies on nearest neighbours search. The Local Outlier Factor (LOF) algorithm is an unsupervised anomaly detection method which computes the local density deviation of a given data point with respect to its neighbors.
#
# Preselected parameter k is the number of neighbors the LOF calculation is considering. The LOF is a calculation that looks at the neighbors of a certain point to find out its density and compare this to the density of other points. With k defined, the k-distance can be calculated, which is the distance of a point to its kth neighbor.
#
#
# The k-distance is used to calculate the reachability distance. This distance measure is simply the maximum of the distance of two points and the k-distance of the second point.
#
# $reachability-dist(a,b) = max\{k-distance(b), dist(a,b)\}$
#
#
# The reach-dist is then used to calculate still another concept — the local reachability density (lrd). To get the lrd for a point a, we will first calculate the reachability distance of a to all its k nearest neighbors and take the average of that number. The lrd is then simply the inverse of that average.
#
# $lrd(a) = \frac{1}{sum(reach-dist(a,n))/k}$
#
#
# The lrd of each point will then be compared to the lrd of their k neighbors. More specifically, k ratios of the lrd of each point to its neighboring points will be calculated and averaged. The LOF is basically the average ratio of the lrds of the neighbors of a to the lrd of a. If the ratio is greater than 1, the density of point a is on average smaller than the density of its neighbors and, thus, from point a, we have to travel longer distances to get to the next point or cluster of points than from a’s neighbors to their next neighbors.
#
# The LOF of a point tells the density of this point compared to the density of its neighbors. If the density of a point is much smaller than the densities of its neighbors (LOF ≫1), the point is far from dense areas and, hence, an outlier.
#
# References:
# Breunig, M. M., Kriegel, H. P., Ng, R. T., & Sander, J. (2000, May). LOF: identifying density-based local outliers. In ACM sigmod record (Vol. 29, №2, pp. 93–104). ACM.

# %%
type(transformed_data) #numpy.ndarray
#transformed_data.shape #(10000, 100)
# Out:
# numpy.ndarray

# %%
#unique0, counts0 = np.unique(transformed_data, return_counts=True)
#dict(zip(unique0, counts0))

# %% [markdown]
# # Parameter Selection
# Various value of K is tried in the model.
# When k<213, the classification result is 1:9999
# When k>=213, the classification result is 214:9786
#
# Since in the dataset, 9786 data points are in one cluster, 213 points in one cluster, and 1 point by itself.
#
# To better detect outlier, k is selected as 300.

# %%
from sklearn.neighbors import LocalOutlierFactor
print(__doc__)

X=transformed_data
clf = LocalOutlierFactor(n_neighbors=300, metric='euclidean')
y_pred = clf.fit_predict(X)
X_scores = clf.negative_outlier_factor_
# Out:
# Automatically created module for IPython interactive environment

# %%
X_scores.shape
# Out:
# (10000,)

# %%
#type(y_pred)#numpy.ndarray
unique, counts = np.unique(y_pred, return_counts=True)
dict(zip(unique, counts))
# Out:
# {-1: 214, 1: 9786}

# %% [markdown]
# # Dimension Reduction
# Since the dimension of the feature is large, we cannot visualize it. PCA is used to reduce dimension of data.
#
# The number of PCA component is decided by using the ratio of variance explained by each of the selected components. The first component explained 97% of the variance, the second component explained 2% of the variance, and the third component explaned less than 0.1% of the variance. Therefore, the first two components were selected.
#
# Same classification result obtained after PCA compared with before PCA.

# %%
#Use PCA to extract key features and visualization 
# %matplotlib inline

import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler 


scaler=preprocessing.StandardScaler().fit(X) 
X_transformed=scaler.transform(X) 

print("shape of train data before pca", X_transformed.shape)


N_components=2
Data_pca = PCA(n_components=N_components).fit(X_transformed)
X_pca = Data_pca.transform(X_transformed)

print("shape of train data after pca", X_pca.shape)
# Out:
# Loaded backend module://matplotlib_inline.backend_inline version unknown.
# shape of train data before pca (10000, 100)
# shape of train data after pca (10000, 2)

# %%
unique2, counts2 = np.unique(X_pca, return_counts=True)
dict(zip(unique2, counts2))
# Out:
# {-1.4758444833445024: 9786,
#  -0.011173010394326947: 213,
#  -0.0016509923684520503: 9786,
#  7.414574845530451: 1,
#  18.536462531702927: 1,
#  67.77088985522794: 213}

# %%
print("variance explained", Data_pca.explained_variance_ratio_ )
# Out:
# variance explained [9.99656346e-01 3.43653708e-04]

# %%
y_pred_pca = clf.fit_predict(X_pca)
X_scores_pca = clf.negative_outlier_factor_


unique_pca, counts_pca = np.unique(y_pred_pca, return_counts=True)
dict(zip(unique_pca, counts_pca))
# Out:
# {-1: 214, 1: 9786}

# %% [markdown]
# # Visualization
#
# The plot visualize the data after PCA.
# The red circles are where the data points are clustered and have higher density. The larger circle on the upper left is a cluster having 9786 points, and the small circle on lower right is the cluster having 213 points. The single point on the lower left is one outlier that does not have any neighbor.
#
# Since we selected number of neighbors to be 500, in this case, the 213 points cluster would all be considered as outliers.

# %%
plt.title("Local Outlier Factor (LOF)")
plt.scatter(X_pca[:, 0], X_pca[:, 1], color='k', s=3., label='Data points')
# plot circles with radius proportional to the outlier scores
radius = (X_scores_pca.max() - X_scores_pca) / (X_scores_pca.max() - X_scores_pca.min())
plt.scatter(X_pca[:, 0], X_pca[:, 1], s=1000 * radius, edgecolors='r',
            facecolors='none', label='Outlier scores')
plt.axis('tight')

legend = plt.legend(loc='upper right')
legend.legendHandles[0]._sizes = [10]
legend.legendHandles[1]._sizes = [20]
plt.show()

# %% [markdown]
# #### Not use following
# #### Train SOM
#
# Here we train the Self Organizing Map on our vectorized logs and output a few vizualiztions of the trained model

# %%
map_size = 16
model = train(transformed_data, map_size, 0, 2)
# Out:
#  Training...
#  random_initialization took: 0.006000 seconds
#  Rough training...
#  radius_ini: 6.000000 , radius_final: 1.000000, trainlen: 100
#
#  epoch: 1 ---> elapsed time:  0.142000, quantization error: 35.949628
# training dataset is of size {inp.shape[0]}
#  epoch: 2 ---> elapsed time:  0.170000, quantization error: 1.229027
#
#  epoch: 3 ---> elapsed time:  0.122000, quantization error: 0.117411
#
#  epoch: 4 ---> elapsed time:  0.118000, quantization error: 0.103476
#
#  epoch: 5 ---> elapsed time:  0.122000, quantization error: 0.093404
#
#  epoch: 6 ---> elapsed time:  0.114000, quantization error: 0.084052
#
#  epoch: 7 ---> elapsed time:  0.249000, quantization error: 0.075401
#
#  epoch: 8 ---> elapsed time:  0.123000, quantization error: 0.067429
#
#  epoch: 9 ---> elapsed time:  0.132000, quantization error: 0.060111
#
#  epoch: 10 ---> elapsed time:  0.132000, quantization error: 0.053420
#
#  epoch: 11 ---> elapsed time:  0.132000, quantization error: 0.047327
#
#  epoch: 12 ---> elapsed time:  0.122000, quantization error: 0.041802
#
#  epoch: 13 ---> elapsed time:  0.128000, quantization error: 0.036812
#
#  epoch: 14 ---> elapsed time:  0.124000, quantization error: 0.032324
#
#  epoch: 15 ---> elapsed time:  0.130000, quantization error: 0.028307
#
#  epoch: 16 ---> elapsed time:  0.188000, quantization error: 0.024726
#
#  epoch: 17 ---> elapsed time:  0.121000, quantization error: 0.021544
#
#  epoch: 18 ---> elapsed time:  0.122000, quantization error: 0.018515
#
#  epoch: 19 ---> elapsed time:  0.115000, quantization error: 0.016046
#
#  epoch: 20 ---> elapsed time:  0.121000, quantization error: 0.013885
#
#  epoch: 21 ---> elapsed time:  0.119000, quantization error: 0.012003
#
#  epoch: 22 ---> elapsed time:  0.123000, quantization error: 0.010373
#
#  epoch: 23 ---> elapsed time:  0.121000, quantization error: 0.008968
#
#  epoch: 24 ---> elapsed time:  0.115000, quantization error: 0.007764
#
#  epoch: 25 ---> elapsed time:  0.115000, quantization error: 0.006737
#
#  epoch: 26 ---> elapsed time:  0.115000, quantization error: 0.005867
#
#  epoch: 27 ---> elapsed time:  0.092000, quantization error: 0.005133
#
#  epoch: 28 ---> elapsed time:  0.176000, quantization error: 0.004519
#
#  epoch: 29 ---> elapsed time:  0.118000, quantization error: 0.004008
#
#  epoch: 30 ---> elapsed time:  0.101000, quantization error: 0.003585
#
#  epoch: 31 ---> elapsed time:  0.104000, quantization error: 0.003238
#
#  epoch: 32 ---> elapsed time:  0.127000, quantization error: 0.002955
#
#  epoch: 33 ---> elapsed time:  0.115000, quantization error: 0.002718
#
#  epoch: 34 ---> elapsed time:  0.142000, quantization error: 0.002452
#
#  epoch: 35 ---> elapsed time:  0.204000, quantization error: 0.002297
#
#  epoch: 36 ---> elapsed time:  0.087000, quantization error: 0.002170
#
#  epoch: 37 ---> elapsed time:  0.114000, quantization error: 0.002064
#
#  epoch: 38 ---> elapsed time:  0.118000, quantization error: 0.001978
#
#  epoch: 39 ---> elapsed time:  0.127000, quantization error: 0.001905
#
#  epoch: 40 ---> elapsed time:  0.125000, quantization error: 0.001841
#
#  epoch: 41 ---> elapsed time:  0.114000, quantization error: 0.001784
#
#  epoch: 42 ---> elapsed time:  0.143000, quantization error: 0.001730
#
#  epoch: 43 ---> elapsed time:  0.101000, quantization error: 0.001677
#
#  epoch: 44 ---> elapsed time:  0.133000, quantization error: 0.001622
#
#  epoch: 45 ---> elapsed time:  0.134000, quantization error: 0.001564
#
#  epoch: 46 ---> elapsed time:  0.123000, quantization error: 0.001501
#
#  epoch: 47 ---> elapsed time:  0.117000, quantization error: 0.001430
#
#  epoch: 48 ---> elapsed time:  0.110000, quantization error: 0.001351
#
#  epoch: 49 ---> elapsed time:  0.101000, quantization error: 0.001263
#
#  epoch: 50 ---> elapsed time:  0.080000, quantization error: 0.001198
#
#  epoch: 51 ---> elapsed time:  0.114000, quantization error: 0.001059
#
#  epoch: 52 ---> elapsed time:  0.109000, quantization error: 0.000931
#
#  epoch: 53 ---> elapsed time:  0.113000, quantization error: 0.000777
#
#  epoch: 54 ---> elapsed time:  0.123000, quantization error: 0.000648
#
#  epoch: 55 ---> elapsed time:  0.128000, quantization error: 0.000543
#
#  epoch: 56 ---> elapsed time:  0.133000, quantization error: 0.000388
#
#  epoch: 57 ---> elapsed time:  0.108000, quantization error: 0.000230
#
#  epoch: 58 ---> elapsed time:  0.381000, quantization error: 0.000166
#
#  epoch: 59 ---> elapsed time:  0.208000, quantization error: 0.000085
#
#  epoch: 60 ---> elapsed time:  0.119000, quantization error: 0.000104
#
#  epoch: 61 ---> elapsed time:  0.126000, quantization error: 0.000055
#
#  epoch: 62 ---> elapsed time:  0.125000, quantization error: 0.000026
#
#  epoch: 63 ---> elapsed time:  0.331000, quantization error: 0.000017
#
#  epoch: 64 ---> elapsed time:  0.282000, quantization error: 0.000008
#
#  epoch: 65 ---> elapsed time:  0.111000, quantization error: 0.000006
#
#  epoch: 66 ---> elapsed time:  0.218000, quantization error: 0.000004
#
#  epoch: 67 ---> elapsed time:  0.062000, quantization error: 0.000003
#
#  epoch: 68 ---> elapsed time:  0.118000, quantization error: 0.000003
#
#  epoch: 69 ---> elapsed time:  0.115000, quantization error: 0.000003
#
#  epoch: 70 ---> elapsed time:  0.105000, quantization error: 0.000003
#
#  epoch: 71 ---> elapsed time:  0.170000, quantization error: 0.000003
#
#  epoch: 72 ---> elapsed time:  0.109000, quantization error: 0.000003
#
#  epoch: 73 ---> elapsed time:  0.117000, quantization error: 0.000003
#
#  epoch: 74 ---> elapsed time:  0.115000, quantization error: 0.000003
#
#  epoch: 75 ---> elapsed time:  0.113000, quantization error: 0.000003
#
#  epoch: 76 ---> elapsed time:  0.333000, quantization error: 0.000003
#
#  epoch: 77 ---> elapsed time:  0.130000, quantization error: 0.000003
#
#  epoch: 78 ---> elapsed time:  0.113000, quantization error: 0.000003
#
#  epoch: 79 ---> elapsed time:  0.118000, quantization error: 0.000003
#
#  epoch: 80 ---> elapsed time:  0.112000, quantization error: 0.000003
#
#  epoch: 81 ---> elapsed time:  0.116000, quantization error: 0.000003
#
#  epoch: 82 ---> elapsed time:  0.113000, quantization error: 0.000003
#
#  epoch: 83 ---> elapsed time:  0.114000, quantization error: 0.000003
#
#  epoch: 84 ---> elapsed time:  0.117000, quantization error: 0.000003
#
#  epoch: 85 ---> elapsed time:  0.131000, quantization error: 0.000003
#
#  epoch: 86 ---> elapsed time:  0.129000, quantization error: 0.000003
#
#  epoch: 87 ---> elapsed time:  0.112000, quantization error: 0.000003
#
#  epoch: 88 ---> elapsed time:  0.106000, quantization error: 0.000003
#
#  epoch: 89 ---> elapsed time:  0.133000, quantization error: 0.000003
#
#  epoch: 90 ---> elapsed time:  0.105000, quantization error: 0.000003
#
#  epoch: 91 ---> elapsed time:  0.112000, quantization error: 0.000003
#
#  epoch: 92 ---> elapsed time:  0.101000, quantization error: 0.000003
#
#  epoch: 93 ---> elapsed time:  0.122000, quantization error: 0.000003
#
#  epoch: 94 ---> elapsed time:  0.139000, quantization error: 0.000003
#
#  epoch: 95 ---> elapsed time:  0.104000, quantization error: 0.000003
#
#  epoch: 96 ---> elapsed time:  0.124000, quantization error: 0.000003
#
#  epoch: 97 ---> elapsed time:  0.123000, quantization error: 0.000003
#
#  epoch: 98 ---> elapsed time:  0.185000, quantization error: 0.000003
#
#  epoch: 99 ---> elapsed time:  0.112000, quantization error: 0.000003
#
#  epoch: 100 ---> elapsed time:  0.099000, quantization error: 0.000003
#
#  Finetune training...
#  radius_ini: 1.333333 , radius_final: 1.000000, trainlen: 5
#
#  epoch: 1 ---> elapsed time:  0.140000, quantization error: 0.000003
#
#  epoch: 2 ---> elapsed time:  0.142000, quantization error: 0.000003
#
#  epoch: 3 ---> elapsed time:  0.141000, quantization error: 0.000003
#
#  epoch: 4 ---> elapsed time:  0.111000, quantization error: 0.000003
#
#  epoch: 5 ---> elapsed time:  0.119000, quantization error: 0.000003
#
#  Final quantization error: 0.000003
#  train took: 14.624000 seconds

# %%
from sompy.visualization.hitmap import HitMapView
model.cluster(3)
hits  = HitMapView(10,10,"Clustering",text_size=7)
a=hits.show(model, labelsize=12)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-188ef60ff19f> in <module>
#       2 model.cluster(3)
#       3 hits  = HitMapView(10,10,"Clustering",text_size=7)
# ----> 4 a=hits.show(model, labelsize=12)
#
# TypeError: show() got an unexpected keyword argument 'labelsize'

# %%
from sompy.visualization.mapview import View2D
view2D  = View2D(10,10,"rand data",text_size=10)
view2D.show(model, col_sz=4, which_dim="all", denormalize=True)

# %%
from sompy.visualization.bmuhits import BmuHitsView

vhts  = BmuHitsView(10,10,"Hits Map",text_size=7)
vhts.show(model, anotate=True, onlyzeros=False, labelsize=12, cmap="Greys", logaritmic=False)

# %%
 m = model.codebook.matrix.reshape([16, 16, transformed_data.shape[1]])

# %% [markdown]
# #### Measure Distances
#
# We want to generate some baseline summary statistics of our model

# %%
#then = time.
distances = get_anomaly_score(transformed_data, 8, m)

print(max(distances))
print(min(distances))
print(np.mean(distances))
print(np.std(distances))

# %%
plt.hist(distances)
plt.show()

# %%
threshold = 3*np.std(distances) + np.mean(distances)
threshold

# %%
threshold

# %%
count = 0
for i, j in enumerate(distances):
    if j > threshold:
        print(j, data.loc[i])
        count += 1
print(count)

# %%
data.message.value_counts()

# %% [markdown]
# #### Test

# %%
infer(w2vmodel,m,'rootCMDusrlocalbinmonitorapachestatsshdevnull', data,threshold)

# %%
infer(w2vmodel,m,'DEBUGProcessedoutofpackages', data,threshold)

# %%
infer(w2vmodel,m,'ThreadodcsserverINFOComposetypestatedoneComposedone ', data,threshold)

# %%
infer(w2vmodel,m,'FSKSDNKSDNKSfdhfhfdhfdhfdhfdhfd  hfhf dlksfljscomLDN', data,threshold)

# %%
infer(w2vmodel,m,'this is not a log message',data,threshold)

# %%
infer(w2vmodel,m,'message',data,threshold)
