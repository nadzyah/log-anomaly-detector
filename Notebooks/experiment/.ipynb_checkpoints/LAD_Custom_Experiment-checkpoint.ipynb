# %% [markdown]
# # LAD Custom experiment
#
# Here we test the prediction quality regarding to the existence of spaces in word2vec model
#
# In the original implementation the w2v model removes all the numbers and spaces in a log message and create a one single word:
#
# `2019-04-12 01:13:20 [DEBUG] Processed 181 out of 181 packages` → `["DEBUGProcessedoutofpackages"]`
#
# Here we want to test the original implementation and our approach:
#
# `2019-04-12 01:13:20 [DEBUG] Processed 181 out of 181 packages` → `["DEBUG", "Processed", "out", "of", "packages"]`
#
# Also we tried to use LOF with our word2vec approach here

# %% [markdown]
# ### Import packages

# %%
import os
import time
import numpy as np
import logging
import sompy
from multiprocessing import Pool
from itertools import product
import pandas as pd
import re
import gensim as gs
import matplotlib.pyplot as plt
from scipy.spatial.distance import cosine
from sklearn.preprocessing import normalize
from sklearn.neighbors import LocalOutlierFactor
import matplotlib.pyplot as plt
# Out:
# CACHEDIR=/home/nadzya/.cache/matplotlib
# Using fontManager instance from /home/nadzya/.cache/matplotlib/fontlist-v330.json
# Loaded backend module://ipykernel.pylab.backend_inline version unknown.
# Loaded backend module://ipykernel.pylab.backend_inline version unknown.
# NumExpr defaulting to 4 threads.

# %%
# import logging

# logger = logging.getLogger()
# logger.disabled = True
# logging.disable()

# %% [markdown]
# # Original Approach

# %% [markdown]
# ### Define Functions
#
# #### 1. Log Preprocesing
#
# One assumption that all these functions use is that we instantly convert our data into a pandas dataframe that has a "message" column containing the relevent information for us.
#
# **We then treat each individual log line as a "word", cleaning it by removing all non-alphabet charcters including white spaces.**

# %%
def _preprocess(data):
    for col in data.columns:
        if col == "message":
            data[col] = data[col].apply(_clean_message)
        else:
            data[col] = data[col].apply(to_str)

    data = data.fillna("EMPTY")
    
def _clean_message(line):
    """Remove all none alphabetical characters from message strings."""
    return "".join(
        re.findall("[a-zA-Z]+", line)
    )  # Leaving only a-z in there as numbers add to anomalousness quite a bit

def to_str(x):
    """Convert all non-str lists to string lists for Word2Vec."""
    ret = " ".join([str(y) for y in x]) if isinstance(x, list) else str(x)
    return ret

# %% [markdown]
# #### 2. Text Encoding
#
# Here we employ the gensim implementation of Word2Vec to encode our logs as fixed length numerical vectors. Logs are noteably not the natural usecase for word2vec, but this appraoch attemps to leverage the fact that logs lines themselves, like words, have a context, so encoding a log based on its co-occurence with other logs does make some intuitive sense.

# %%
def create(words, vector_length, window_size):
    """Create new word2vec model."""
    w2vmodel = {}
    for col in words.columns:
        if col in words:
            w2vmodel[col] = gs.models.Word2Vec([list(words[col])], min_count=1, size=vector_length, 
                                     window=window_size, seed=42, workers=1, iter=550, sg=0)
        else:
            #_LOGGER.warning("Skipping key %s as it does not exist in 'words'" % col)
            pass
        
    return w2vmodel

def one_vector(new_D, w2vmodel):
    """Create a single vector from model."""
    transforms = {}
    for col in w2vmodel.keys():
        if col in new_D:
            transforms[col] = w2vmodel[col].wv[new_D[col]]

    new_data = []

    for i in range(len(transforms["message"])):
        logc = np.array(0)
        for _, c in transforms.items():
            if c.item(i):
                logc = np.append(logc, c[i])
            else:
                logc = np.append(logc, [0, 0, 0, 0, 0])
        new_data.append(logc)

    return np.array(new_data, ndmin=2)

# %% [markdown]
# #### 3. Model Training
#
# Here we employ the SOMPY implementation of the Self-Organizing Map to train our model. This function simply makes it a bit easier for the user to interact with the sompy training requirements. This function returns a trained model.
#
# The trained model object also has a method called codebook.matrix() which allows the user access directly to the trained self organizing map itself. If the map successfull converged then it should consist of nodes in our N-dimensional log space that are well ordered and provide an approximation to the topology of the logs in our training set.
#
# During training we also, compute the distances of our training data to the trained map as a baseline to build a threashold.

# %%
def train(inp, map_size, iterations, parallelism):
    print(f'training dataset is of size {inp.shape[0]}')
    mapsize = [map_size, map_size]
    np.random.seed(42)
    som = sompy.SOMFactory.build(inp, mapsize , initialization='random')
    som.train(n_job=parallelism, train_rough_len=100,train_finetune_len=5)
    model = som.codebook.matrix.reshape([map_size, map_size, inp.shape[1]])
    
    #distances = get_anomaly_score(inp, 8, model)
    #threshold = 3*np.std(distances) + np.mean(distances)
    
    return som #,threshold

# %% [markdown]
# #### 4. Generating Anomaly Scores
#
# One of the key elements of this approach is quantifying the distance between our logs and the nodes on our self organizing map. The two functions below, taken together, represent a parrallel implementation for performing this calculaton.

# %%
def get_anomaly_score(logs, parallelism, model):
    parameters = [[x, model] for x in logs]
    pool = Pool(parallelism)
    dist = pool.map(calculate_anomaly_score, parameters) 
    pool.close()
    pool.join()
    
    return dist

def calculate_anomaly_score(parameters):
    log = parameters[0]
    model = parameters[1]
    """Compute a distance of a log entry to elements of SOM."""
    dist_smallest = np.inf
    for x in range(model.shape[0]):
        for y in range(model.shape[1]):
            dist = cosine(model[x][y], log) 
            #dist = np.linalg.norm(model[x][y] - log)
            if dist < dist_smallest:
                dist_smallest = dist
    return dist_smallest

# %% [markdown]
# #### 5. Model Inference / Prediction
#
# Here we are making an inference about a new log message. This is done by scoring the incoming log and evaluating whether or not it passess a certain threshold value.
#
#
# Ideally our word2vec has been monitoring our application long enough to have seen all the logs. So, if we get a known log we can simply look up its vector representation
#
# One downside with word2vec is that its quite brittle when it comes to incorporating words that haven't been seen before. In this example, we will retrain the W2Vmodel if our new log has not been seen by the before.

# %%
def infer(w2v, som, log, data, threshold):
    
    log =  pd.DataFrame({"message":log},index=[1])
    _preprocess(log)
    
    if log.message.iloc[0] in list(w2v['message'].wv.vocab.keys()):
        vector = w2v["message"].wv[log.message.iloc[0]]
    else:
        w2v = gs.models.Word2Vec([[log.message.iloc[0]] + list(data["message"])], 
                                 min_count=1, size=25, window=3, seed=42, workers=1, iter=550, sg=0)
        vector = w2v.wv[log.message.iloc[0]]
    
    score = get_anomaly_score([vector], 1, som)
    
    if score < threshold:
        return 0, score
    else:
        return 1, score

# %% [markdown]
# ## Implementation

# %% [markdown]
# ### Get logs from file

# %%
data_path = r"file:///home/nadzya/Apps/log-anomaly-detector/validation_data/slx.json"
data = pd.DataFrame(pd.read_json(data_path, orient=str).message)
data
# Out:
#                                                 message
# 0     <189>date=2021-11-24 time=12:11:11 devname="SL...
# 1     <190>date=2021-11-24 time=12:11:49 devname="SL...
# 2     <189>date=2021-11-24 time=12:11:59 devname="SL...
# 3     <189>date=2021-11-24 time=12:12:14 devname="SL...
# 4     <189>date=2021-11-24 time=12:12:45 devname="SL...
# ...                                                 ...
# 9995  <189>date=2021-11-25 time=15:17:00 devname="SL...
# 9996  <189>date=2021-11-25 time=17:48:37 devname="SL...
# 9997  <189>date=2021-11-25 time=18:32:31 devname="SL...
# 9998  <189>date=2021-11-25 time=17:48:37 devname="SL...
# 9999  <189>date=2021-11-25 time=18:32:31 devname="SL...
#
# [10000 rows x 1 columns]

# %% [markdown]
# ### Preprocessing

# %%
preprocessed_data = data.copy()
_preprocess(preprocessed_data)

# First 5 prepocessed messages
pd.DataFrame(preprocessed_data.message).head()
# Out:
#                                              message
# 0  datetimedevnameSLXFGVMdevidFGVMlogidtypeevents...
# 1  datetimedevnameSLXFGVMdevidFGVMlogidtypeevents...
# 2  datetimedevnameSLXFGVMdevidFGVMlogidtypeevents...
# 3  datetimedevnameSLXFGVMdevidFGVMlogidtypeevents...
# 4  datetimedevnameSLXFGVMdevidFGVMlogidtypeevents...

# %% [markdown]
# Let's see how many logs are there for each preprocessed word-log. We display top 5

# %%
x = preprocessed_data.message.value_counts()
for i in x.keys()[:5]:
    print(i, x[i])
# Out:
# datetimedevnameSLXFGVMdevidFGVMlogidtypeeventsubtypesystemlevelinformationvdrooteventtimetzlogdescOutdatedreportfilesdeletedmsgDeleteoldreportfiles 711
#  453
#  217
# datetimedevnameSLXFGVMdevidFGVMlogidtypeeventsubtypesystemlevelinformationvdrooteventtimetzlogdescAdminlogoutsuccessfulsnuserADMINuisshmethodsshsrcipdstipactionlogoutstatussuccessdurationreasonexitmsgAdministratorADMINloggedoutfromssh 201
# ... 146

# %% [markdown]
# ### Word2Vec for such words

# %%
w2v = create(words=preprocessed_data, vector_length=25, window_size=5)
# Out:
# consider setting layer size to a multiple of 4 for greater performance
# collecting all words and their counts
# PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# collected 3332 word types from a corpus of 10000 raw words and 1 sentences
# Loading a fresh vocabulary
# effective_min_count=1 retains 3332 unique words (100% of original 3332, drops 0)
# effective_min_count=1 leaves 10000 word corpus (100% of original 10000, drops 0)
# deleting the raw counts dictionary of 3332 items
# sample=0.001 downsamples 83 most-common words
# downsampling leaves estimated 7513 word corpus (75.1% of prior 10000)
# estimated required memory for 3332 words and 25 dimensions: 2332400 bytes
# resetting layer weights
# training model with 1 workers on 3332 vocabulary and 25 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 1 : training on 10000 raw words (7567 effective words) took 0.0s, 545385 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 2 : training on 10000 raw words (7447 effective words) took 0.0s, 534032 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 3 : training on 10000 raw words (7543 effective words) took 0.0s, 510222 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 4 : training on 10000 raw words (7553 effective words) took 0.0s, 553222 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 5 : training on 10000 raw words (7608 effective words) took 0.0s, 557982 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 6 : training on 10000 raw words (7529 effective words) took 0.0s, 379702 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 7 : training on 10000 raw words (7492 effective words) took 0.0s, 331033 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 8 : training on 10000 raw words (7482 effective words) took 0.0s, 414717 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 9 : training on 10000 raw words (7513 effective words) took 0.0s, 470033 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH -
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 550 : training on 10000 raw words (7542 effective words) took 0.0s, 566850 effective words/s
# training on a 5500000 raw words (4131745 effective words) took 9.6s, 431572 effective words/s

# %%
log_vectors = one_vector(preprocessed_data, w2v)

# %%
print(log_vectors.shape)
print(log_vectors[:, 1:].shape)
log_vectors = log_vectors[:, 1:]
# Out:
# (10000, 26)
# (10000, 25)

# %% [markdown]
# ### Train SOM

# %%
map_size = 24
som = train(log_vectors, map_size=map_size, iterations=0, parallelism=2)
# Out:
#  Training...
#  random_initialization took: 0.002000 seconds
#  Rough training...
#  radius_ini: 8.000000 , radius_final: 1.333333, trainlen: 100
# training dataset is of size 10000
#  epoch: 1 ---> elapsed time:  0.190000, quantization error: 8.481039
#
#  epoch: 2 ---> elapsed time:  0.183000, quantization error: 4.295275
#
#  epoch: 3 ---> elapsed time:  0.335000, quantization error: 3.784516
#
#  epoch: 4 ---> elapsed time:  0.217000, quantization error: 3.694883
#
#  epoch: 5 ---> elapsed time:  0.174000, quantization error: 3.661672
#
#  epoch: 6 ---> elapsed time:  0.097000, quantization error: 3.647184
#
#  epoch: 7 ---> elapsed time:  0.086000, quantization error: 3.639375
#
#  epoch: 8 ---> elapsed time:  0.089000, quantization error: 3.634820
#
#  epoch: 9 ---> elapsed time:  0.085000, quantization error: 3.630343
#
#  epoch: 10 ---> elapsed time:  0.092000, quantization error: 3.627564
#
#  epoch: 11 ---> elapsed time:  0.096000, quantization error: 3.623197
#
#  epoch: 12 ---> elapsed time:  0.085000, quantization error: 3.618891
#
#  epoch: 13 ---> elapsed time:  0.084000, quantization error: 3.612805
#
#  epoch: 14 ---> elapsed time:  0.085000, quantization error: 3.607089
#
#  epoch: 15 ---> elapsed time:  0.084000, quantization error: 3.603001
#
#  epoch: 16 ---> elapsed time:  0.085000, quantization error: 3.598005
#
#  epoch: 17 ---> elapsed time:  0.091000, quantization error: 3.594296
#
#  epoch: 18 ---> elapsed time:  0.175000, quantization error: 3.591329
#
#  epoch: 19 ---> elapsed time:  0.166000, quantization error: 3.588501
#
#  epoch: 20 ---> elapsed time:  0.179000, quantization error: 3.585430
#
#  epoch: 21 ---> elapsed time:  0.164000, quantization error: 3.582315
#
#  epoch: 22 ---> elapsed time:  0.156000, quantization error: 3.579110
#
#  epoch: 23 ---> elapsed time:  0.186000, quantization error: 3.576076
#
#  epoch: 24 ---> elapsed time:  0.170000, quantization error: 3.572677
#
#  epoch: 25 ---> elapsed time:  0.145000, quantization error: 3.569182
#
#  epoch: 26 ---> elapsed time:  0.171000, quantization error: 3.565444
#
#  epoch: 27 ---> elapsed time:  0.174000, quantization error: 3.561757
#
#  epoch: 28 ---> elapsed time:  0.162000, quantization error: 3.557657
#
#  epoch: 29 ---> elapsed time:  0.139000, quantization error: 3.553656
#
#  epoch: 30 ---> elapsed time:  0.098000, quantization error: 3.549834
#
#  epoch: 31 ---> elapsed time:  0.098000, quantization error: 3.545959
#
#  epoch: 32 ---> elapsed time:  0.183000, quantization error: 3.542051
#
#  epoch: 33 ---> elapsed time:  0.192000, quantization error: 3.537904
#
#
#  epoch: 75 ---> elapsed time:  0.193000, quantization error: 3.167125
#
#  epoch: 76 ---> elapsed time:  0.188000, quantization error: 3.152573
#
#  epoch: 77 ---> elapsed time:  0.182000, quantization error: 3.136394
#
#  epoch: 78 ---> elapsed time:  0.187000, quantization error: 3.119914
#
#  epoch: 79 ---> elapsed time:  0.188000, quantization error: 3.103274
#
#  epoch: 80 ---> elapsed time:  0.202000, quantization error: 3.085239
#
#  epoch: 81 ---> elapsed time:  0.184000, quantization error: 3.065837
#
#  epoch: 82 ---> elapsed time:  0.193000, quantization error: 3.045085
#
#  epoch: 83 ---> elapsed time:  0.194000, quantization error: 3.025960
#
#  epoch: 84 ---> elapsed time:  0.202000, quantization error: 3.005570
#
#  epoch: 85 ---> elapsed time:  0.200000, quantization error: 2.985346
#
#  epoch: 86 ---> elapsed time:  0.165000, quantization error: 2.964310
#
#  epoch: 87 ---> elapsed time:  0.112000, quantization error: 2.942496
#
#  epoch: 88 ---> elapsed time:  0.189000, quantization error: 2.917938
#
#  epoch: 89 ---> elapsed time:  0.354000, quantization error: 2.892798
#
#  epoch: 90 ---> elapsed time:  0.208000, quantization error: 2.863345
#
#  epoch: 91 ---> elapsed time:  0.206000, quantization error: 2.830296
#
#  epoch: 92 ---> elapsed time:  0.196000, quantization error: 2.800005
#
#  epoch: 93 ---> elapsed time:  0.186000, quantization error: 2.769887
#
#  epoch: 94 ---> elapsed time:  0.213000, quantization error: 2.733955
#
#  epoch: 95 ---> elapsed time:  0.186000, quantization error: 2.697041
#
#  epoch: 96 ---> elapsed time:  0.235000, quantization error: 2.660821
#
#  epoch: 97 ---> elapsed time:  0.495000, quantization error: 2.621930
#
#  epoch: 98 ---> elapsed time:  0.571000, quantization error: 2.580583
#
#  epoch: 99 ---> elapsed time:  0.319000, quantization error: 2.537640
#
#  epoch: 100 ---> elapsed time:  0.445000, quantization error: 2.487095
#
#  Finetune training...
#  radius_ini: 2.000000 , radius_final: 1.000000, trainlen: 5
#
#  epoch: 1 ---> elapsed time:  0.602000, quantization error: 2.433881
#
#  epoch: 2 ---> elapsed time:  0.341000, quantization error: 2.815435
#
#  epoch: 3 ---> elapsed time:  0.289000, quantization error: 2.690200
#
#  epoch: 4 ---> elapsed time:  0.195000, quantization error: 2.544154
#
#  epoch: 5 ---> elapsed time:  0.211000, quantization error: 2.364274
#
#  Final quantization error: 2.364274
#  train took: 23.417000 seconds

# %%
model = som.codebook.matrix.reshape([map_size, map_size, log_vectors.shape[1]])

# %%
model.shape
# Out:
# (24, 24, 25)

# %%
anomaly_scores = get_anomaly_score(log_vectors, parallelism=4, model=model)

# %%
threshold = 3*np.std(anomaly_scores) + np.mean(anomaly_scores)
threshold
# Out:
# 0.6420240434693314

# %% [markdown]
# # With Custom Approach

# %% [markdown]
# ### Define Functions
#
# #### 1. Log Preprocesing
#
# One assumption that all these functions use is that we instantly convert our data into a pandas dataframe that has a "message" column containing the relevent information for us.
#
# We then treat each individual log line as a set of words, cleaning it by removing all non-alphabet charcters.
#
# We keep white spaces and return a list of wordss

# %%
def _preprocess_custom(data):
    for col in data.columns:
        if col == "message":
            data[col] = data[col].apply(_clean_message_custom)
        else:
            data[col] = data[col].apply(to_str_custom)

    data = data.fillna("EMPTY")
    
def _clean_message_custom(line):
    """Remove all none alphabetical characters from message strings."""
    words = list(re.findall("[a-zA-Z]+", line))
    return words

def to_str_custom(x):
    """Convert all non-str lists to string lists for Word2Vec."""
    ret = " ".join([str(y) for y in x]) if isinstance(x, list) else str(x)
    return ret

# %% [markdown]
# #### Text encoding

# %%
def create_custom(logs, vector_length, window_size):
    """Create new word2vec model."""
    model = gs.models.Word2Vec(sentences=list(logs), size=vector_length, window=window_size)
    return model

def get_vectors(model, logs, vector_length):
    """Return logs as list of vectorized words"""
    vectors = []
    for x in logs:
        temp = []
        for word in x:
            if word in model.wv:
                temp.append(model.wv[word])
            else:
                temp.append(np.array([0]*vector_length))
        vectors.append(temp)
    return vectors

def _log_words_to_one_vector(log_words_vectors):
        result = []
        log_array_transposed = np.array(log_words_vectors, dtype=object).transpose()
        for coord in log_array_transposed:
            result.append(np.mean(coord))
        return result

def vectorized_logs_to_single_vectors(vectors):
    """Represent log messages as vectors according to the vectors
    of the words in these logs

    :params vectors: list of log messages, represented as list of words vectors
            [[wordvec11, wordvec12], [wordvec21, wordvec22], ...]
    """
    result = []
    for log_words_vector in vectors:
        result.append(_log_words_to_one_vector(log_words_vector))
    return np.array(result)

# %% [markdown]
# **LOF for training**

# %%
def train_lof(X, eps, min_samples):
    lof = LocalOutlierFactor(metric='euclidean')
    pred = lof.fit_predict(X)
    lof_model = LocalOutlierFactor(metric='euclidean', novelty=True)
    lof_model.fit(X)
    return pred, lof_model

# %% [markdown]
# #### Prediction

# %%
def infer_custom(w2v, som, log, logs_list, threshold):
    
    log = pd.DataFrame({"message": log}, index=[1])
    _preprocess_custom(log)
    
    vector = []
    w2v = gs.models.Word2Vec([log.message.iloc[0]] + logs_list,
                             min_count=1, size=25, window=5)
    for word in log.message.iloc[0]:
        if word in w2v.wv.vocab.keys():
            vector.append(w2v.wv[word])
        else:
            vector.append(np.array([0]*25))
    
    one_vector = _log_words_to_one_vector(vector)
    
    score = get_anomaly_score([one_vector], 1, som)
    
    if score < threshold:
        return 0, score
    else:
        return 1, score

# %%
def infer_lof(w2v, lof, log, loglist):
    log = pd.DataFrame({"message": log}, index=[1])
    _preprocess_custom(log)
    
    vector = []
    w2v = gs.models.Word2Vec([log.message.iloc[0]] + loglist,
                             min_count=1, size=25, window=5)
    for word in log.message.iloc[0]:
        if word in w2v.wv.vocab.keys():
            vector.append(w2v.wv[word])
        else:
            vector.append(np.array([0]*25))
    one_vector = _log_words_to_one_vector(vector)
    pred = lof.predict([one_vector])
    score = abs(lof.score_samples([one_vector])[0])
    if pred[0] == -1:
        return 1, score
    return 0, score

# %% [markdown]
# ## Implementation

# %% [markdown]
# ### Preprocessing

# %%
custom_preproc_data = data.copy()
_preprocess_custom(custom_preproc_data)

# First 5 prepocessed messages
pd.DataFrame(custom_preproc_data.message).head()
# Out:
#                                              message
# 0  [date, time, devname, SLX, FG, VM, devid, FGVM...
# 1  [date, time, devname, SLX, FG, VM, devid, FGVM...
# 2  [date, time, devname, SLX, FG, VM, devid, FGVM...
# 3  [date, time, devname, SLX, FG, VM, devid, FGVM...
# 4  [date, time, devname, SLX, FG, VM, devid, FGVM...

# %%
logs_list = list(custom_preproc_data.message)
print(logs_list[0])
# Out:
# ['date', 'time', 'devname', 'SLX', 'FG', 'VM', 'devid', 'FGVM', 'logid', 'type', 'event', 'subtype', 'vpn', 'level', 'notice', 'vd', 'root', 'eventtime', 'tz', 'logdesc', 'Progress', 'IPsec', 'phase', 'msg', 'progress', 'IPsec', 'phase', 'action', 'negotiate', 'remip', 'locip', 'remport', 'locport', 'outintf', 'port', 'cookies', 'ddabf', 'c', 'user', 'N', 'A', 'group', 'N', 'A', 'useralt', 'N', 'A', 'xauthuser', 'N', 'A', 'xauthgroup', 'N', 'A', 'assignip', 'N', 'A', 'vpntunnel', 'test', 'status', 'success', 'init', 'local', 'mode', 'main', 'dir', 'outbound', 'stage', 'role', 'initiator', 'result', 'OK']

# %%
w2v_custom = create_custom(logs_list, vector_length=25, window_size=5)
# Out:
# consider setting layer size to a multiple of 4 for greater performance
# collecting all words and their counts
# PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# collected 1196 word types from a corpus of 672382 raw words and 10000 sentences
# Loading a fresh vocabulary
# effective_min_count=5 retains 509 unique words (42% of original 1196, drops 687)
# effective_min_count=5 leaves 671377 word corpus (99% of original 672382, drops 1005)
# deleting the raw counts dictionary of 1196 items
# sample=0.001 downsamples 68 most-common words
# downsampling leaves estimated 275898 word corpus (41.1% of prior 671377)
# estimated required memory for 509 words and 25 dimensions: 356300 bytes
# resetting layer weights
# training model with 3 workers on 509 vocabulary and 25 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# worker thread finished; awaiting finish of 2 more threads
# worker thread finished; awaiting finish of 1 more threads
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 1 : training on 672382 raw words (276051 effective words) took 0.2s, 1325889 effective words/s
# worker thread finished; awaiting finish of 2 more threads
# worker thread finished; awaiting finish of 1 more threads
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 2 : training on 672382 raw words (276080 effective words) took 0.3s, 1000964 effective words/s
# worker thread finished; awaiting finish of 2 more threads
# worker thread finished; awaiting finish of 1 more threads
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 3 : training on 672382 raw words (276046 effective words) took 0.3s, 1048453 effective words/s
# worker thread finished; awaiting finish of 2 more threads
# worker thread finished; awaiting finish of 1 more threads
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 4 : training on 672382 raw words (275450 effective words) took 0.2s, 1293259 effective words/s
# worker thread finished; awaiting finish of 2 more threads
# worker thread finished; awaiting finish of 1 more threads
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 5 : training on 672382 raw words (275260 effective words) took 0.2s, 1288408 effective words/s
# training on a 3361910 raw words (1378887 effective words) took 1.2s, 1163049 effective words/s

# %%
vectors_custom = get_vectors(model=w2v_custom, logs=logs_list, vector_length=25)

# %%
logs_as_vectors = vectorized_logs_to_single_vectors(vectors_custom)

# %% [markdown]
#
#  epoch: 79 ---> elapsed time:  0.302000, quantization error: 0.297967
#
#  epoch: 80 ---> elapsed time:  0.301000, quantization error: 0.286080
#
#  epoch: 81 ---> elapsed time:  0.186000, quantization error: 0.274745
#
#  epoch: 82 ---> elapsed time:  0.181000, quantization error: 0.262724
#
#  epoch: 83 ---> elapsed time:  0.288000, quantization error: 0.254489
#
#  epoch: 84 ---> elapsed time:  0.414000, quantization error: 0.242021
#
#  epoch: 85 ---> elapsed time:  0.150000, quantization error: 0.231335
#
#  epoch: 86 ---> elapsed time:  0.219000, quantization error: 0.221440
#
#  epoch: 87 ---> elapsed time:  0.098000, quantization error: 0.209509
#
#  epoch: 88 ---> elapsed time:  0.176000, quantization error: 0.198530
#
#  epoch: 89 ---> elapsed time:  0.247000, quantization error: 0.187311
#
#  epoch: 90 ---> elapsed time:  0.200000, quantization error: 0.175370
#
#  epoch: 91 ---> elapsed time:  0.207000, quantization error: 0.160897
#
#  epoch: 92 ---> elapsed time:  0.183000, quantization error: 0.153978
#
#  epoch: 93 ---> elapsed time:  0.193000, quantization error: 0.144980
#
#  epoch: 94 ---> elapsed time:  0.187000, quantization error: 0.139544
#
#  epoch: 95 ---> elapsed time:  0.210000, quantization error: 0.132337
#
#  epoch: 96 ---> elapsed time:  0.221000, quantization error: 0.123093
#
#  epoch: 97 ---> elapsed time:  0.192000, quantization error: 0.116313
#
#  epoch: 98 ---> elapsed time:  0.227000, quantization error: 0.109396
#
#  epoch: 99 ---> elapsed time:  0.194000, quantization error: 0.103461
#
#  epoch: 100 ---> elapsed time:  0.211000, quantization error: 0.097967
#
#  Finetune training...
#  radius_ini: 2.000000 , radius_final: 1.000000, trainlen: 5
#
#  epoch: 1 ---> elapsed time:  0.202000, quantization error: 0.091131
#
#  epoch: 2 ---> elapsed time:  0.244000, quantization error: 0.185374
#
#  epoch: 3 ---> elapsed time:  0.180000, quantization error: 0.145324
#
#  epoch: 4 ---> elapsed time:  0.195000, quantization error: 0.113373
#
#  epoch: 5 ---> elapsed time:  0.192000, quantization error: 0.088457
#
#  Final quantization error: 0.088457
#  train took: 24.257000 seconds

# %%
model_custom = som_custom.codebook.matrix.reshape([map_size, map_size, logs_as_vectors.shape[1]])

# %%
anomaly_scores_custom = get_anomaly_score(logs_as_vectors, parallelism=4, model=model_custom)

# %%
threshold_custom = 3*np.std(anomaly_scores_custom) + np.mean(anomaly_scores_custom)
threshold_custom
# Out:
# 0.5187193441096365

# %%
labeled_data_som = data.copy()
labeled_data_som["score"] = anomaly_scores_custom
list(labeled_data_som.loc[labeled_data_som["score"] > threshold_custom]["message"])
# Out:
# []

# %% [markdown]
# ### Train LOF

# %%
clusters_lof, lof_model = train_lof(logs_as_vectors, 0.5, 10)

# %%
labeled_data = data.copy()
labeled_data["cluster"] = clusters_lof
labeled_data["score"] = abs(lof_model.score_samples(logs_as_vectors))
list(zip(labeled_data.loc[labeled_data["cluster"] == -1]["message"], labeled_data.loc[labeled_data["cluster"] == -1]["score"]))
# Out:
# [('<189>date=2021-11-24 time=12:11:11 devname="SLX-FG-VM-166" devid="FGVM010000010982" logid="0101037127" type="event" subtype="vpn" level="notice" vd="root" eventtime=1637745072926351051 tz="+0300" logdesc="Progress IPsec phase 1" msg="progress IPsec phase 1" action="negotiate" remip=172.17.42.203 locip=172.17.42.1 remport=500 locport=500 outintf="port5" cookies="81ddabf5934c2569/0000000000000000" user="N/A" group="N/A" useralt="N/A" xauthuser="N/A" xauthgroup="N/A" assignip=N/A vpntunnel="test" status="success" init="local" mode="main" dir="outbound" stage=1 role="initiator" result="OK"',
#   146435734.92972642),
#  ('<189>date=2021-11-24 time=12:13:15 devname="SLX-FG-VM-166" devid="FGVM010000010982" logid="0101037127" type="event" subtype="vpn" level="notice" vd="root" eventtime=1637745196931875929 tz="+0300" logdesc="Progress IPsec phase 1" msg="progress IPsec phase 1" action="negotiate" remip=172.17.42.203 locip=172.17.42.1 remport=500 locport=500 outintf="port5" cookies="da2479fd77339c8a/0000000000000000" user="N/A" group="N/A" useralt="N/A" xauthuser="N/A" xauthgroup="N/A" assignip=N/A vpntunnel="test" status="success" init="local" mode="main" dir="outbound" stage=1 role="initiator" result="OK"',
#   329464614.2963955),
#  ('<189>date=2021-11-24 time=12:17:39 devname="SLX-FG-VM-166" devid="FGVM010000010982" logid="0000000013" type="traffic" subtype="forward" level="notice" vd="root" eventtime=1637745461932072069 tz="+0300" srcip=93.125.5.100 srcname="sip.telecom.by" srcport=23919 srcintf="port2" srcintfrole="wan" dstip=37.17.54.156 dstname="37.17.54.156" dstport=20643 dstintf="port4" dstintfrole="lan" sessionid=188257872 proto=17 action="accept" policyid=96 policytype="policy" poluuid="d1382da0-a4b6-51e9-1f28-9639f07021c5" service="udp/20643" dstcountry="Belarus" srccountry="Belarus" trandisp="dnat" tranip=172.17.15.3 tranport=23797 duration=36 sentbyte=784 rcvdbyte=980 sentpkt=7 rcvdpkt=7 appcat="unscanned"',
#   849821498.6497203),
#  ('<190>date=2021-11-24 time=12:21:39 devname="SLX-FG-VM-166" devid="FGVM010000010982" logid="0814044032" type="utm" subtype="voip" eventtype="voip" level="information" vd="root" eventtime=1637745700854910817 tz="+0300" session_id=188257872 epoch=0 event_id=13318 srcip=172.17.15.3 src_port=5060 dstip=93.125.5.100 dst_port=5060 proto=17 src_int="port4" dst_int="port2" policy_id=96 profile="default" voip_proto="sip" kind="call" action="permit" status="start" duration=0 dir="session_origin" call_id="c6334672-c7aa-123a-c792-005056a0cd31" from="sip:375173361195@sip.telecom.by" to="sip:3274802@sip.telecom.by"',
#   494171889.77228034),
#  ('<189>date=2021-11-24 time=12:22:35 devname="SLX-FG-VM-165" devid="FGVM010000010981" logid="0100032106" type="event" subtype="system" level="notice" vd="root" eventtime=1637745756508555586 tz="+0300" logdesc="NTP server status changes to resolvable" user="NTP_DAEMON" ui="NONE" field="date-time" msg="The IPv4 ntp server, pool.ntp.org(178.124.134.106), is determined resolvable at Wed Nov 24 12:22:36 2021"',
#   237119504.39705977),
#  ('<189>date=2021-11-24 time=12:22:50 devname="SLX-FG-VM-166" devid="FGVM010000010982" logid="0000000013" type="traffic" subtype="forward" level="notice" vd="root" eventtime=1637745770372065938 tz="+0300" srcip=93.125.5.100 srcname="sip.telecom.by" srcport=13567 srcintf="port2" srcintfrole="wan" dstip=37.17.54.156 dstname="37.17.54.156" dstport=20645 dstintf="port4" dstintfrole="lan" sessionid=188257872 proto=17 action="accept" policyid=96 policytype="policy" poluuid="d1382da0-a4b6-51e9-1f28-9639f07021c5" service="udp/20645" dstcountry="Belarus" srccountry="Belarus" trandisp="dnat" tranip=172.17.15.3 tranport=23241 duration=66 sentbyte=784 rcvdbyte=980 sentpkt=7 rcvdpkt=7 appcat="unscanned"',
#   849821498.6497203),
#  ('<189>date=2021-11-24 time=12:23:37 devname="SLX-FG-VM-166" devid="FGVM010000010982" logid="
devname="SLX-FG-VM-166" devid="FGVM010000010982" logid="0814044032" type="utm" subtype="voip" eventtype="voip" level="information" vd="root" eventtime=1637755056344375649 tz="+0300" session_id=188257872 epoch=0 event_id=13350 srcip=172.17.15.3 src_port=5060 dstip=93.125.5.100 dst_port=5060 proto=17 src_int="port4" dst_int="port2" policy_id=96 profile="default" voip_proto="sip" kind="call" action="permit" status="start" duration=0 dir="session_origin" call_id="8e810d34-c7c0-123a-c792-005056a0cd31" from="sip:375173361195@sip.telecom.by" to="sip:3747156@sip.telecom.by"',
#   1069186376.6619841),
#  ('<190>date=2021-11-24 time=14:58:23 devname="SLX-FG-VM-166" devid="FGVM010000010982" logid="0814044032" type="utm" subtype="voip" eventtype="voip" level="information" vd="root" eventtime=1637755104399760751 tz="+0300" session_id=188257872 epoch=0 event_id=13351 srcip=172.17.15.3 src_port=5060 dstip=93.125.5.100 dst_port=5060 proto=17 src_int="port4" dst_int="port2" policy_id=96 profile="default" voip_proto="sip" kind="call" action="permit" status="start" duration=0 dir="session_origin" call_id="ab25c52e-c7c0-123a-c792-005056a0cd31" from="sip:375173361195@sip.telecom.by" to="sip:2605918@sip.telecom.by"',
#   1229134033.04697),
#  ('<189>date=2021-11-24 time=14:58:46 devname="SLX-FG-VM-166" devid="FGVM010000010982" logid="0000000013" type="traffic" subtype="forward" level="notice" vd="root" eventtime=1637755126412075162 tz="+0300" srcip=93.125.5.100 srcname="sip.telecom.by" srcport=10403 srcintf="port2" srcintfrole="wan" dstip=37.17.54.156 dstname="37.17.54.156" dstport=20661 dstintf="port4" dstintfrole="lan" sessionid=188257872 proto=17 action="accept" policyid=96 policytype="policy" poluuid="d1382da0-a4b6-51e9-1f28-9639f07021c5" service="udp/20661" dstcountry="Belarus" srccountry="Belarus" trandisp="dnat" tranip=172.17.15.3 tranport=26447 duration=67 sentbyte=756 rcvdbyte=952 sentpkt=7 rcvdpkt=7 appcat="unscanned"',
#   849821498.6497203),
#  ('<189>date=2021-11-24 time=15:00:34 devname="SLX-FG-VM-166" devid="FGVM010000010982" logid="0000000013" type="traffic" subtype="forward" level="notice" vd="root" eventtime=1637755234852052165 tz="+0300" srcip=45.134.144.52 srcname="45.134.144.52" srcport=5104 srcintf="port2" srcintfrole="wan" dstip=37.17.54.157 dstname="mail.solidex.by" dstport=5060 dstintf="port4" dstintfrole="lan" sessionid=294250192 proto=17 action="deny" policyid=97 policytype="policy" poluuid="f70b9c46-a4f8-51e9-ecd7-f8dbb494bfaa" service="SIP" dstcountry="Belarus" srccountry="Reserved" trandisp="dnat" tranip=172.17.32.3 tranport=5060 duration=0 sentbyte=0 rcvdbyte=0 sentpkt=0 appcat="unscanned" crscore=30 craction=131072 crlevel="high"',
#   11548892.537723592),
#  ('<189>date=2021-11-24 time=15:01:11 devname="SLX-FG-VM-166" devid="FGVM010000010982" logid="0101037127" type="event" subtype="vpn" level="notice" vd="root" eventtime=1637755272290880995 tz="+0300" logdesc="Progress IPsec phase 1" msg="progress IPsec phase 1" action="negotiate" remip=172.17.42.203 locip=172.17.42.1 remport=500 locport=500 outintf="port5" cookies="cf8506e6db382ec7/0000000000000000" user="N/A" group="N/A" useralt="N/A" xauthuser="N/A" xauthgroup="N/A" assignip=N/A vpntunnel="test" status="success" init="local" mode="main" dir="outbound" stage=1 role="initiator" result="OK"',
#   321289.2944659398),
#  ('<189>date=2021-11-24 time=15:01:41 devname="SLX-FG-VM-166" devid="FGVM010000010982" logid="0101037127" type="event" subtype="vpn" level="notice" vd="root" eventtime=1637755303288688176 tz="+0300" logdesc="Progress IPsec phase 1" msg="progress IPsec phase 1" action="negotiate" remip=172.17.42.203 locip=172.17.42.1 remport=500 locport=500 outintf="port5" cookies="29c64768b91df679/0000000000000000" user="N/A" group="N/A" useralt="N/A" xauthuser="N/A" xauthgroup="N/A" assignip=N/A vpntunnel="test" status="success" init="local" mode="main" dir="outbound" stage=1 role="initiator" result="OK"',
#   478824.07188123313),
#  ('<189>date=2021-11-24 time=15:04:17 devname="SLX-FG-VM-166" devid="FGVM010000010982" logid="0101037127" type="event" subtype="vpn" level="notice" vd="root" eventtime=1637755458302274349 tz="+0300" logdesc="Progress IPsec phase 1" msg="progress IPsec phase 1" action="negotiate" remip=172.17.42.203 locip=172.17.42.1 remport=500 locport=500 outintf="port5" cookies="009967ffeaeb6dd9/0000000000000000" user="N/A" group="N/A" useralt="N/A" xauthuser="N/A" xauthgroup="N/A" assignip=N/A vpntunnel="test" status="success" init="local" mode="main" dir="outbound" stage=1 role="initiator" result="OK"',
#   17179106.49786245),
#  ('<189>date=2021-11-24 time=15:05:19 devname="SLX-FG-VM-166" devid="FGVM010000010982" logid="0101037127" type="event" subtype="vpn" level="notice" vd="root" eventtime=1637755520309784984 tz="+0300" logdesc="Progress IPsec phase 1" msg="progress IPsec phase 1" action="negotiate" remip=172.17.42.203 locip=172.17.42.1 remport=500 locport=500 outintf="port5" cookies="2eef989778241191/0000000000000000" user="N/A" group="N/A" useralt="N/A" xauthuser="N/A" xauthgroup="N/A" assignip=N/A vpntunnel="test" status="success" init="local" mode="main" dir="outbound" stage=1 role="initiator" result="OK"',
#   194358427.75462055),
#  ('<189>date=2021-11-24 time=15:06:21 devname="SLX-FG-VM-166" devid="FGVM010000010982" logid="0101037127" type="event" subtype="vpn" level="notice" vd="root" eventtime=1637755582310129676 tz="+0300" logdesc="Progress IPsec phase 1" msg="progress IPsec phase 1" action="negotiate" remip=172.17.42.203 locip=172.17.42.1 remport=500 locport=500 outintf="port5" cookies="3f30f024ff59cebe/0000000000000000" user="N/A" group="N/A" useralt="N/A" xauthuser="N/A" xauthgroup="N/A" assignip=N/A vpntunnel="test" status="success" init="local" mode="main" dir="outbound" stage=1 role="initiator" result="OK"',
#   138559.37984110453),
# ...
#   1.575184033556686),
#  ('<189>date=2021-11-25 time=18:15:29 devname="SLX-FG-VM-166" devid="FGVM010000010982" logid="0101037127" type="event" subtype="vpn" level="notice" vd="root" eventtime=1637
status="success" init="local" mode="main" dir="outbound" stage=1 role="initiator" result="OK"',
#   470318.85225488275),
#  ('<189>date=2021-11-25 time=18:13:56 devname="SLX-FG-VM-166" devid="FGVM010000010982" logid="0101037127" type="event" subtype="vpn" level="notice" vd="root" eventtime=1637853236949190941 tz="+0300" logdesc="Progress IPsec phase 1" msg="progress IPsec phase 1" action="negotiate" remip=195.137.160.145 locip=37.17.54.156 remport=500 locport=500 outintf="port2" cookies="4ccf78180a5b732c/0000000000000000" user="N/A" group="N/A" useralt="N/A" xauthuser="N/A" xauthgroup="N/A" assignip=N/A vpntunnel="cloud-inet" status="success" init="local" mode="main" dir="outbound" stage=1 role="initiator" result="OK"',
#   53663.54941953274),
#  ('<189>date=2021-11-25 time=18:14:26 devname="SLX-FG-VM-166" devid="FGVM010000010982" logid="0101037127" type="event" subtype="vpn" level="notice" vd="root" eventtime=1637853267951466728 tz="+0300" logdesc="Progress IPsec phase 1" msg="progress IPsec phase 1" action="negotiate" remip=195.137.160.145 locip=37.17.54.156 remport=500 locport=500 outintf="port2" cookies="1e70540e368d29db/0000000000000000" user="N/A" group="N/A" useralt="N/A" xauthuser="N/A" xauthgroup="N/A" assignip=N/A vpntunnel="cloud-inet" status="success" init="local" mode="main" dir="outbound" stage=1 role="initiator" result="OK"',
#   59682341.28364052),
#  ('<189>date=2021-11-25 time=18:15:29 devname="SLX-FG-VM-166" devid="FGVM010000010982" logid="0101037127" type="event" subtype="vpn" level="notice" vd="root" eventtime=1637853329949505328 tz="+0300" logdesc="Progress IPsec phase 1" msg="progress IPsec phase 1" action="negotiate" remip=212.98.168.67 locip=80.94.224.70 remport=500 locport=500 outintf="port1" cookies="e8ba8a8e61bdf5b0/0000000000000000" user="N/A" group="N/A" useralt="N/A" xauthuser="N/A" xauthgroup="N/A" assignip=N/A vpntunnel="belpost" status="success" init="local" mode="main" dir="outbound" stage=1 role="initiator" result="OK"',
#   115160530.4994973),
#  ('<189>date=2021-11-25 time=18:16:00 devname="SLX-FG-VM-166" devid="FGVM010000010982" logid="0101037127" type="event" subtype="vpn" level="notice" vd="root" eventtime=1637853360949094211 tz="+0300" logdesc="Progress IPsec phase 1" msg="progress IPsec phase 1" action="negotiate" remip=195.137.160.145 locip=37.17.54.156 remport=500 locport=500 outintf="port2" cookies="22c443f5d5110eb7/0000000000000000" user="N/A" group="N/A" useralt="N/A" xauthuser="N/A" xauthgroup="N/A" assignip=N/A vpntunnel="cloud-inet" status="success" init="local" mode="main" dir="outbound" stage=1 role="initiator" result="OK"',
#   186675.854027961),
#  ('<189>date=2021-11-25 time=18:20:39 devname="SLX-FG-VM-166" devid="FGVM010000010982" logid="0101037127" type="event" subtype="vpn" level="notice" vd="root" eventtime=1637853639945824926 tz="+0300" logdesc="Progress IPsec phase 1" msg="progress IPsec phase 1" action="negotiate" remip=195.137.160.145 locip=37.17.54.156 remport=500 locport=500 outintf="port2" cookies="143e7bb9dd2b3bf9/0000000000000000" user="N/A" group="N/A" useralt="N/A" xauthuser="N/A" xauthgroup="N/A" assignip=N/A vpntunnel="cloud-inet" status="success" init="local" mode="main" dir="outbound" stage=1 role="initiator" result="OK"',
#   26910421.09414319),
#  ('<189>date=2021-11-25 time=18:21:10 devname="SLX-FG-VM-166" devid="FGVM010000010982" logid="0101037127" type="event" subtype="vpn" level="notice" vd="root" eventtime=1637853670945280398 tz="+0300" logdesc="Progress IPsec phase 1" msg="progress IPsec phase 1" action="negotiate" remip=195.137.160.145 locip=37.17.54.156 remport=500 locport=500 outintf="port2" cookies="dbf0b6c014569f5c/0000000000000000" user="N/A" group="N/A" useralt="N/A" xauthuser="N/A" xauthgroup="N/A" assignip=N/A vpntunnel="cloud-inet" status="success" init="local" mode="main" dir="outbound" stage=1 role="initiator" result="OK"',
#   350734146.2337493),
#  ('<189>date=2021-11-25 time=18:21:10 devname="SLX-FG-VM-166" devid="FGVM010000010982" logid="0101037127" type="event" subtype="vpn" level="notice" vd="root" eventtime=1637853670945433885 tz="+0300" logdesc="Progress IPsec phase 1" msg="progress IPsec phase 1" action="negotiate" remip=212.98.168.67 locip=80.94.224.70 remport=500 locport=500 outintf="port1" cookies="82110be52e4c14a0/0000000000000000" user="N/A" group="N/A" useralt="N/A" xauthuser="N/A" xauthgroup="N/A" assignip=N/A vpntunnel="belpost" status="success" init="local" mode="main" dir="outbound" stage=1 role="initiator" result="OK"',
#   437218.5028994644),
#  ('<189>date=2021-11-25 time=18:22:12 devname="SLX-FG-VM-166" devid="FGVM010000010982" logid="0101037127" type="event" subtype="vpn" level="notice" vd="root" eventtime=1637853732944320550 tz="+0300" logdesc="Progress IPsec phase 1" msg="progress IPsec phase 1" action="negotiate" remip=195.137.160.145 locip=37.17.54.156 remport=500 locport=500 outintf="port2" cookies="8bb816159e886ebf/0000000000000000" user="N/A" group="N/A" useralt="N/A" xauthuser="N/A" xauthgroup="N/A" assignip=N/A vpntunnel="cloud-inet" status="success" init="local" mode="main" dir="outbound" stage=1 role="initiator" result="OK"',
#   102388877.99882047),
#  ('<189>date=2021-11-25 time=18:22:42 devname="SLX-FG-VM-166" devid="FGVM010000010982" logid="0101037127" type="event" subtype="vpn" level="notice" vd="root" eventtime=1637853763944499056 tz="+0300" logdesc="Progress IPsec phase 1" msg="progress IPsec phase 1" action="negotiate" remip=172.17.42.203 locip=172.17.42.1 remport=500 locport=500 outintf="port5" cookies="7b69ad7f1173a7aa/0000000000000000" user="N/A" group="N/A" useralt="N/A" xauthuser="N/A" xauthgroup="N/A" assignip=N/A vpntunnel="test" status="success" init="local" mode="main" dir="outbound" stage=1 role="initiator" result="OK"',
#   1.515606509250457),
#  ...]

# %%
abs(lof_model.score_samples([logs_as_vectors[0]]))
# Out:
# array([1.46435735e+08])

# %% [markdown]
# # Prediciton

# %%
import logging

logger = logging.getLogger()
logger.disabled = True
logging.disable()

# %% [markdown]
# **This is a test message**

# %%
infer(w2v, model, "Blah blah blah blah blah", preprocessed_data, threshold)
# Out:
# (0, [0.3722438085106896])

# %%
infer_custom(w2v_custom, model_custom, "Blah blah blah blah blah", logs_list, threshold_custom)
# Out:
# (0, [0.19565447289247972])

# %%
infer_lof(w2v_custom, lof_model, "Blah blah blah blah blah", logs_list)
# Out:
# (1, 138.99111612570522)

# %% [markdown]
# **<182>Dec 07 14:16:16 dataform  172.17.17.100 - - [07/Dec/2021:14:16:16 +0300] "POST /cgi-bin/.%2e/.%2e/.%2e/.%2e/etc/passwd HTTP/1.1" 400 5604 "-" "curl/7.68.0"**

# %%
infer(w2v, model, "<182>Dec 07 14:16:16 www.solidex.by  172.17.17.100 - - [07/Dec/2021:14:16:16 +0300] \"POST /cgi-bin/.%2e/.%2e/.%2e/.%2e/etc/passwd HTTP/1.1\" 400 5604 \"-\" \"curl/7.68.0\"", preprocessed_data, threshold)
# Out:
# (0, [0.35968568935536405])

# %%
infer_custom(w2v_custom, model_custom, "<182>Dec 07 14:16:16 www.solidex.by  172.17.17.100 - - [07/Dec/2021:14:16:16 +0300] \"POST /cgi-bin/.%2e/.%2e/.%2e/.%2e/etc/passwd HTTP/1.1\" 400 5604 \"-\" \"curl/7.68.0\"", logs_list, threshold_custom)
# Out:
# (0, [0.4220896498352418])

# %%
infer_lof(w2v_custom, lof_model, "<182>Dec 07 14:16:16 www.solidex.by  172.17.17.100 - - [07/Dec/2021:14:16:16 +0300] \"POST /cgi-bin/.%2e/.%2e/.%2e/.%2e/etc/passwd HTTP/1.1\" 400 5604 \"-\" \"curl/7.68.0\"", logs_list)
# Out:
# (1, 30721349944.490498)

# %%
infer_lof(w2v_custom, lof_model, "<158>Nov 25 12:25:32 195-137-160-145 nginx-access 80.94.224.36 - - [25/Nov/2021:12:25:30 +0300] \"GET / HTTP/1.1\" 200 3717 \"-\" \"Go-http-client/1.1\"", logs_list)
# Out:
# (1, 126.72853545253577)

# %% [markdown]
# **<179>Dec 07 14:51:17 dataform  [Wed Dec 07 14:51:17.120946 2021] [auth_basic:error] [pid 2179734:tid 139663791892224] [client 172.17.17.100:44992] AH01617: user webadmin: authentication failure for "/register": Password Mismatch***

# %%
infer(w2v, model, "<179>Dec 07 14:51:17 www.solidex.by  [Wed Dec 07 14:51:17.120946 2021] [auth_basic:error] [pid 2179734:tid 139663791892224] [client 172.17.17.100:44992] AH01617: user webadmin: authentication failure for \"/register\": Password Mismatch", preprocessed_data, threshold)
# Out:
# (0, [0.3635520823701228])

# %%
infer_custom(w2v_custom, model_custom, "<179>Dec 07 14:51:17 www.solidex.by  [Wed Dec 07 14:51:17.120946 2021] [auth_basic:error] [pid 2179734:tid 139663791892224] [client 172.17.17.100:44992] AH01617: user webadmin: authentication failure for \"/register\": Password Mismatch", logs_list, threshold_custom)
# Out:
# (0, [0.3975525108111003])

# %%
infer_lof(w2v_custom, lof_model, "<179>Dec 07 14:51:17 www.solidex.by  [Wed Dec 07 14:51:17.120946 2021] [auth_basic:error] [pid 2179734:tid 139663791892224] [client 172.17.17.100:44992] AH01617: user webadmin: authentication failure for \"/register\": Password Mismatch", logs_list,)
# Out:
# (1, 138.89114167778123)

# %% [markdown]
# **<179>Dec 07 12:10:53 smtplib.SMTPRecipientsRefused: {'doesntexist@solidex.by': (550, b'5.1.1 <doesntexist@solidex.by>: Recipient address rejected: User unknown in virtual mailbox table')}**

# %%
infer(w2v, model, "<179>Dec 07 12:10:53 smtplib.SMTPRecipientsRefused: {'doesntexist@solidex.by': (550, b'5.1.1 <doesntexist@solidex.by>: Recipient address rejected: User unknown in virtual mailbox table')}", preprocessed_data, threshold)
# Out:
# (0, [0.3730278962278192])

# %%
infer_custom(w2v_custom, model_custom, "<179>Dec 07 12:10:53 smtplibb.SMTPRecipientsRefused: {'doesntexist@solidex.by': (550, b'5.1.1 <doesntexist@solidex.by>: Recipient address rejected: User unknown in virtual mailbox table')}", logs_list, threshold_custom)
# Out:
# (0, [0.38588894346301306])

# %%
infer_lof(w2v_custom, lof_model, "<179>Dec 07 12:10:53 smtplibb.SMTPRecipientsRefused: {'doesntexist@solidex.by': (550, b'5.1.1 <doesntexist@solidex.by>: Recipient address rejected: User unknown in virtual mailbox table')}", logs_list)
# Out:
# (1, 24544729828.150448)

# %% [markdown]
# **<158>Dec 07 14:24:59 195-137-160-145 nginx-access 2021/11/25 14:24:56 [error] 492#492: *15416147 open() "/var/www/solidex.by/public_html/robots.txt" failed (2: No such file or directory), client: 216.244.66.231, server: , request: "GET /robots.txt HTTP/1.1", host: solidex.by**

# %%
infer(w2v, model, "<158>Dec 07 14:24:59 195-137-160-145 nginx-access 2021/11/25 14:24:56 [error] 492#492: *15416147 open() \"/var/www/solidex.by/public_html/robots.txt\" failed (2: No such file or directory), client: 216.244.66.231, server: , request: \"GET /robots.txt HTTP/1.1\", host: \"solidex.by\"", preprocessed_data, threshold)
# Out:
# (0, [0.376293115902819])

# %%
infer_custom(w2v_custom, model_custom, "<158>Dec 07 14:24:59 195-137-160-145 nginx-access 2021/11/25 14:24:56 [error] 492#492: *15416147 open() \"/var/www/solidex.by/public_html/robots.txt\" failed (2: No such file or directory), client: 216.244.66.231, server: , request: \"GET /robots.txt HTTP/1.1\", host: \"solidex.by\"", logs_list, threshold_custom)
# Out:
# (0, [0.29254015089332286])

# %% [markdown]
# # Visualization

# %%
from sklearn.decomposition import PCA

# %% [markdown]
# ### LOF

# %%
# %pylab inline

outliers = []
for x in clusters_lof:
    if x == -1:
        outliers.append(1)
    else:
        outliers.append(0)

pca = PCA(n_components=2, random_state=0)
data_2d_pca = pca.fit_transform(logs_as_vectors)

scores = lof_model.negative_outlier_factor_
radius = (scores.max() - scores) / (scores.max() - scores.min())

pylab.figure(figsize=(10, 6))
scat = pylab.scatter(data_2d_pca[:, 0], data_2d_pca[:, 1], c=outliers)
pylab.legend(*scat.legend_elements(num='auto'))
# plt.scatter(
#     data_2d_pca[:, 0],
#     data_2d_pca[:, 1],
#     s=1000 * radius,
#     edgecolors="r",
#     facecolors="none"
# )
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/nadzya/.local/lib/python3.8/site-packages/IPython/core/magics/pylab.py:159: UserWarning: pylab import has clobbered these variables: ['product']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %% [markdown]
# ### W2V custom

# %%
pca = PCA(n_components=2, random_state=0)
data_2d_pca = pca.fit_transform(logs_as_vectors)

pylab.figure(figsize=(10, 6))
scat = pylab.scatter(data_2d_pca[:, 0], data_2d_pca[:, 1], c=anomaly_scores_custom > 0.65*threshold_custom)
pylab.legend(*scat.legend_elements(num='auto'))
