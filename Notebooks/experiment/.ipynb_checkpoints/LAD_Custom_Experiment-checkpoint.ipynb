# %% [markdown]
# # LAD Custom experiment
#
# Here we test the prediction quality regarding to the existence of spaces in word2vec model
#
# In the original implementation the w2v model removes all the numbers and spaces in a log message and create a one single word:
#
# `2019-04-12 01:13:20 [DEBUG] Processed 181 out of 181 packages` → `["DEBUGProcessedoutofpackages"]`
#
# Here we want to test the original implementation and our approach:
#
# `2019-04-12 01:13:20 [DEBUG] Processed 181 out of 181 packages` → `["DEBUG", "Processed", "out", "of", "packages"]`

# %% [markdown]
# ### Import packages

# %%
import os
import time
import numpy as np
import logging
import sompy
from multiprocessing import Pool
from itertools import product
import pandas as pd
import re
import gensim as gs
import matplotlib.pyplot as plt
from scipy.spatial.distance import cosine
from sklearn.preprocessing import normalize

import matplotlib.pyplot as plt
# Out:
# CACHEDIR=/home/nadzya/.cache/matplotlib
# Using fontManager instance from /home/nadzya/.cache/matplotlib/fontlist-v330.json
# Loaded backend module://ipykernel.pylab.backend_inline version unknown.
# Loaded backend module://ipykernel.pylab.backend_inline version unknown.
# NumExpr defaulting to 4 threads.

# %%
# import logging

# logger = logging.getLogger()
# logger.disabled = True
# logging.disable()

# %% [markdown]
# # Original Approach

# %% [markdown]
# ### Define Functions
#
# #### 1. Log Preprocesing
#
# One assumption that all these functions use is that we instantly convert our data into a pandas dataframe that has a "message" column containing the relevent information for us.
#
# **We then treat each individual log line as a "word", cleaning it by removing all non-alphabet charcters including white spaces.**

# %%
def _preprocess(data):
    for col in data.columns:
        if col == "message":
            data[col] = data[col].apply(_clean_message)
        else:
            data[col] = data[col].apply(to_str)

    data = data.fillna("EMPTY")
    
def _clean_message(line):
    """Remove all none alphabetical characters from message strings."""
    return "".join(
        re.findall("[a-zA-Z]+", line)
    )  # Leaving only a-z in there as numbers add to anomalousness quite a bit

def to_str(x):
    """Convert all non-str lists to string lists for Word2Vec."""
    ret = " ".join([str(y) for y in x]) if isinstance(x, list) else str(x)
    return ret

# %% [markdown]
# #### 2. Text Encoding
#
# Here we employ the gensim implementation of Word2Vec to encode our logs as fixed length numerical vectors. Logs are noteably not the natural usecase for word2vec, but this appraoch attemps to leverage the fact that logs lines themselves, like words, have a context, so encoding a log based on its co-occurence with other logs does make some intuitive sense.

# %%
def create(words, vector_length, window_size):
    """Create new word2vec model."""
    w2vmodel = {}
    for col in words.columns:
        if col in words:
            w2vmodel[col] = gs.models.Word2Vec([list(words[col])], min_count=1, size=vector_length, 
                                     window=window_size, seed=42, workers=1, iter=550, sg=0)
        else:
            #_LOGGER.warning("Skipping key %s as it does not exist in 'words'" % col)
            pass
        
    return w2vmodel

def one_vector(new_D, w2vmodel):
    """Create a single vector from model."""
    transforms = {}
    for col in w2vmodel.keys():
        if col in new_D:
            transforms[col] = w2vmodel[col].wv[new_D[col]]

    new_data = []

    for i in range(len(transforms["message"])):
        logc = np.array(0)
        for _, c in transforms.items():
            if c.item(i):
                logc = np.append(logc, c[i])
            else:
                logc = np.append(logc, [0, 0, 0, 0, 0])
        new_data.append(logc)

    return np.array(new_data, ndmin=2)

# %% [markdown]
# #### 3. Model Training
#
# Here we employ the SOMPY implementation of the Self-Organizing Map to train our model. This function simply makes it a bit easier for the user to interact with the sompy training requirements. This function returns a trained model.
#
# The trained model object also has a method called codebook.matrix() which allows the user access directly to the trained self organizing map itself. If the map successfull converged then it should consist of nodes in our N-dimensional log space that are well ordered and provide an approximation to the topology of the logs in our training set.
#
# During training we also, compute the distances of our training data to the trained map as a baseline to build a threashold.

# %%
def train(inp, map_size, iterations, parallelism):
    print(f'training dataset is of size {inp.shape[0]}')
    mapsize = [map_size, map_size]
    np.random.seed(42)
    som = sompy.SOMFactory.build(inp, mapsize , initialization='random')
    som.train(n_job=parallelism, train_rough_len=100,train_finetune_len=5)
    model = som.codebook.matrix.reshape([map_size, map_size, inp.shape[1]])
    
    #distances = get_anomaly_score(inp, 8, model)
    #threshold = 3*np.std(distances) + np.mean(distances)
    
    return som #,threshold

# %% [markdown]
# #### 4. Generating Anomaly Scores
#
# One of the key elements of this approach is quantifying the distance between our logs and the nodes on our self organizing map. The two functions below, taken together, represent a parrallel implementation for performing this calculaton.

# %%
def get_anomaly_score(logs, parallelism, model):

    parameters = [[x,model] for x in logs]
    pool = Pool(parallelism)
    dist = pool.map(calculate_anomaly_score, parameters) 
    pool.close()
    pool.join()
    return dist

def calculate_anomaly_score(parameters):
    log = parameters[0]
    model = parameters[1]
    """Compute a distance of a log entry to elements of SOM."""
    dist_smallest = np.inf
    for x in range(model.shape[0]):
        for y in range(model.shape[1]):
            dist = cosine(model[x][y], log) 
            #dist = np.linalg.norm(model[x][y] - log)
            if dist < dist_smallest:
                dist_smallest = dist
    return dist_smallest

# %% [markdown]
# #### 5. Model Inference / Prediction
#
# Here we are making an inference about a new log message. This is done by scoring the incoming log and evaluating whether or not it passess a certain threshold value.
#
#
# Ideally our word2vec has been monitoring our application long enough to have seen all the logs. So, if we get a known log we can simply look up its vector representation
#
# One downside with word2vec is that its quite brittle when it comes to incorporating words that haven't been seen before. In this example, we will retrain the W2Vmodel if our new log has not been seen by the before.

# %%
def infer(w2v, som, log, data, threshold):
    
    log =  pd.DataFrame({"message":log},index=[1])
    _preprocess(log)
    
    if log.message.iloc[0] in list(w2v['message'].wv.vocab.keys()):
        vector = w2v["message"].wv[log.message.iloc[0]]
    else:
        w2v = gs.models.Word2Vec([[log.message.iloc[0]] + list(data["message"])], 
                                 min_count=1, size=25, window=3, seed=42, workers=1, iter=550, sg=0)
        vector = w2v.wv[log.message.iloc[0]]
    
    score = get_anomaly_score([vector], 1, som)
    
    if score < threshold:
        return 0, score
    else:
        return 1, score

# %% [markdown]
# ## Implementation

# %% [markdown]
# ### Get logs from file

# %%
data_path = r"file:///home/nadzya/Apps/log-anomaly-detector/validation_data/solidex.by.json"
data = pd.DataFrame(pd.read_json(data_path, orient=str).message)
data
# Out:
#                                                 message
# 0     <158>Nov 25 12:02:31 195-137-160-145 nginx-acc...
# 1     <158>Nov 25 12:04:11 195-137-160-145 nginx-acc...
# 2     <158>Nov 25 12:15:42 195-137-160-145 nginx-acc...
# 3     <158>Nov 25 12:25:32 195-137-160-145 nginx-acc...
# 4     <158>Nov 25 12:25:22 195-137-160-145 nginx-acc...
# ...                                                 ...
# 9995  <158>Nov 25 16:01:44 195-137-160-145 nginx-acc...
# 9996  <158>Nov 25 13:53:47 195-137-160-145 nginx-acc...
# 9997  <158>Nov 25 15:25:02 195-137-160-145 nginx-acc...
# 9998  <158>Nov 25 14:48:50 195-137-160-145 nginx-acc...
# 9999  <158>Nov 25 16:01:44 195-137-160-145 nginx-acc...
#
# [10000 rows x 1 columns]

# %% [markdown]
# ### Preprocessing

# %%
preprocessed_data = data.copy()
_preprocess(preprocessed_data)

# First 5 prepocessed messages
pd.DataFrame(preprocessed_data.message).head()
# Out:
#                                              message
# 0               NovnginxaccessNovGETHTTPGohttpclient
# 1  NovnginxaccessNovGETcoursesHTTPhttpwwwsolidexb...
# 2               NovnginxaccessNovGETHTTPGohttpclient
# 3               NovnginxaccessNovGETHTTPGohttpclient
# 4               NovnginxaccessNovGETHTTPGohttpclient

# %% [markdown]
# Let's see how many logs are there for each preprocessed word-log. We display top 5

# %%
x = preprocessed_data.message.value_counts()
for i in x.keys()[:5]:
    print(i, x[i])
# Out:
# NovnginxaccessNovGETokompaniiHTTPHealthCheck 3979
# NovnginxaccessNovGETHTTPGohttpclient 3836
# NovnginxaccessNovPOSTwpcronphpdoingwpcronHTTPWordPresshttpwwwsolidexby 734
# NovnginxaccessNovPOSTwploginphpHTTPhttpwwwsolidexbywploginphpMozillaWindowsNTWinxrvGeckoFirefox 702
# NovnginxaccessNovHEADHTTPhttpsolidexbyMozillacompatibleUptimeRobothttpwwwuptimerobotcom 376

# %% [markdown]
# ### Word2Vec for such words

# %%
w2v = create(words=preprocessed_data, vector_length=25, window_size=5)
# Out:
# consider setting layer size to a multiple of 4 for greater performance
# collecting all words and their counts
# PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# collected 29 word types from a corpus of 10000 raw words and 1 sentences
# Loading a fresh vocabulary
# effective_min_count=1 retains 29 unique words (100% of original 29, drops 0)
# effective_min_count=1 leaves 10000 word corpus (100% of original 10000, drops 0)
# deleting the raw counts dictionary of 29 items
# sample=0.001 downsamples 11 most-common words
# downsampling leaves estimated 948 word corpus (9.5% of prior 10000)
# estimated required memory for 29 words and 25 dimensions: 20300 bytes
# resetting layer weights
# training model with 1 workers on 29 vocabulary and 25 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 1 : training on 10000 raw words (974 effective words) took 0.0s, 347605 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 2 : training on 10000 raw words (938 effective words) took 0.0s, 235515 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 3 : training on 10000 raw words (954 effective words) took 0.0s, 231129 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 4 : training on 10000 raw words (947 effective words) took 0.0s, 238125 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 5 : training on 10000 raw words (943 effective words) took 0.0s, 190884 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 6 : training on 10000 raw words (968 effective words) took 0.0s, 144511 effective words/s
# job loop exiting, total 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 7 : training on 10000 raw words (954 effective words) took 0.0s, 112028 effective words/s
# worker exiting, processed 1 jobs
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 8 : training on 10000 raw words (934 effective words) took 0.0s, 145594 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 9 : training on 10000 raw words (976 effective words) took 0.0s, 207693 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 10 : training on 10000 raw words (972 effective words) took 0.0s, 224347 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 11 : training on 10000 raw words (921 effective words) took 0.0s, 81878 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 12 : training on 10000 raw words (922 effective words) took 0.0s, 125844 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 13 : training on 10000 raw words (954 effective words) took 0.0s, 121084 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 14 : training on 10000 raw words (934 effective words) took 0.0s, 57758 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 15 : training on 10000 raw words (946 effective words) took 0.0s, 108750 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 16 : training on 10000 raw words (912 effective words) took 0.0s, 186302 effective words/s
# job loop exiting, total 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 17 : training on 10000 raw words (944 effective words) took 0.0s, 140163 effective words/s
# worker exiting, processed 1 jobs
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 18 : training on 10000 raw words (955 effective words) took 0.0s, 99246 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 19 : training on 10000 raw words (926 effective words) took 0.0s, 245682 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 20 : training on 10000 raw words (945 effective words) took 0.0s, 137824 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 21 : training on 10000 raw words (959 effective words) took 0.0s, 71809 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 22 : training on 10000 raw words (975 effective words) took 0.0s, 189823 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 23 : training on 10000 raw words (967 effective words) took 0.0s, 99028 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 24 : training on 10000 raw words (986 effective words) took 0.0s, 114261 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 25 : training on 10000 raw words (890 effective words) took 0.0s, 79199 effective words/s
# job loop exiting, total 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 26 : training on 10000 raw words (945 effective words) took 0.0s, 107311 effective words/s
# worker exiting, processed 1 jobs
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 27 : training on 10000 raw words (969 effective words) took 0.0s, 125535 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 28 : training on 10000 raw words (946 effective words) took 0.0s, 57410 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 29 : training on 10000 raw words (928 effective words) took 0.0s, 76454 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 30 : training on 10000 raw words (957 effective words) took 0.0s, 143893 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 31 : training on 10000 raw words (937 effective words) took 0.0s, 121542 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 32 : training on 10000 raw words (977 effective words) took 0.0s, 102772 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 33 : training on 10000 raw words (905 effective words) took 0.0s, 113177 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 34 : training on 10000 raw words (975 effective words) took 0.0s, 163530 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 35 : training on 10000 raw words (956 effective words) took 0.0s, 111969 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 36 : training on 10000 raw words (909 effective words) took 0.0s, 133893 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 37 : training on 10000 raw words (914 effective words) took 0.0s, 148949 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 38 : training on 10000 raw words (994 effective words) took 0.0s, 167797 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 39 : training on 10000 raw words (938 effective words) took 0.0s, 147701 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 40 : training on 10000 raw words (927 effective words) took 0.0s, 135109 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 41 : training on 10000 raw words (951 effective words) took 0.0s, 191881 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 42 : training on 10000 raw words (932 effective words) took 0.0s, 85833 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 43 : training on 10000 raw words (943 effective words) took 0.0s, 128702 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 44 : training on 10000 raw words (931 effective words) took 0.0s, 116517 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 45 : training on 10000 raw words (908 effective words) took 0.0s, 148507 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 46 : training on 10000 raw words (951 effective words) took 0.0s, 171609 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 47 : training on 10000 raw words (937 effective words) took 0.0s, 182000 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 48 : training on 10000 raw words (967 effective words) took 0.0s, 182026 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 49 : training on 10000 raw words (1002 effective words) took 0.0s, 104660 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 50 : training on 10000 raw words (953 effective words) took 0.0s, 108521 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 51 : training on 10000 raw words (963 effective words) took 0.0s, 166570 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 52 : training on 10000 raw words (989 effective words) took 0.0s, 139186 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 53 : training on 10000 raw words (909 effective words) took 0.0s, 119711 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 54 : training on 10000 raw words (934 effective words) took 0.0s, 69940 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 55 : training on 10000 raw words (966 effective words) took 0.0s, 53007 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 56 : training on 10000 raw words (898 effective words) took 0.0s, 242186 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 57 : training on 10000 raw words (929 effective words) took 0.0s, 101776 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 58 : training on 10000 raw words (923 effective words) took 0.0s, 118452 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 59 : training on 10000 raw words (974 effective words) took 0.0s, 106383 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 60 : training on 10000 raw words (943 effective words) took 0.0s, 89562 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 61 : training on 10000 raw words (960 effective words) took 0.0s, 142628 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 62 : training on 10000 raw words (1015 effective words) took 0.0s, 105358 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 63 : training on 10000 raw words (916 effective words) took 0.0s, 100845 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 64 : training on 10000 raw words (931 effective words) took 0.0s, 111455 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 65 : training on 10000 raw words (950 effective words) took 0.0s, 120828 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 66 : training on 10000 raw words (957 effective words) took 0.0s, 132852 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 67 : training on 10000 raw words (930 effective words) took 0.0s, 161464 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 68 : training on 10000 raw words (976 effective words) took 0.0s, 88546 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 69 : training on 10000 raw words (922 effective words) took 0.0s, 135515 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 70 : training on 10000 raw words (933 effective words) took 0.0s, 135496 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 71 : training on 10000 raw words (958 effective words) took 0.0s, 139633 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 72 : training on 10000 raw words (982 effective words) took 0.0s, 225188 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 73 : training on 10000 raw words (963 effective words) took 0.0s, 94667 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 74 : training on 10000 raw words (948 effective words) took 0.0s, 138855 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 75 : training on 10000 raw words (922 effective words) took 0.0s, 125979 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 76 : training on 10000 raw words (942 effective words) took 0.0s, 182596 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 77 : training on 10000 raw words (939 effective words) took 0.0s, 118826 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 78 : training on 10000 raw words (986 effective words) took 0.0s, 191140 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 79 : training on 10000 raw words (933 effective words) took 0.0s, 274533 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 80 : training on 10000 raw words (941 effective words) took 0.0s, 104516 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 81 : training on 10000 raw words (969 effective words) took 0.0s, 127960 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 82 : training on 10000 raw words (927 effective words) took 0.0s, 111807 effective words/s
# job loop exiting, total 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# worker exiting, processed 1 jobs
# EPOCH - 83 : training on 10000 raw words (942 effective words) took 0.0s, 95605 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 84 : training on 10000 raw words (928 effective words) took 0.0s, 128930 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 85 : training on 10000 raw words (945 effective words) took 0.0s, 134809 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 86 : training on 10000 raw words (963 effective words) took 0.0s, 125487 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 87 : training on 10000 raw words (941 effective words) took 0.0s, 93690 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 88 : training on 10000 raw words (975 effective words) took 0.0s, 85437 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 89 : training on 10000 raw words (943 effective words) took 0.0s, 75950 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 90 : training on 10000 raw words (904 effective words) took 0.0s, 126389 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 91 : training on 10000 raw words (952 effective words) took 0.0s, 149707 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 92 : training on 10000 raw words (976 effective words) took 0.0s, 314934 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 93 : training on 10000 raw words (960 effective words) took 0.0s, 83380 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 94 : training on 10000 raw words (972 effective words) took 0.0s, 147622 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 95 : training on 10000 raw words (894 effective words) took 0.0s, 160476 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 96 : training on 10000 raw words (934 effective words) took 0.0s, 212030 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 97 : training on 10000 raw words (979 effective words) took 0.0s, 134454 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 98 : training on 10000 raw words (935 effective words) took 0.0s, 158407 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 99 : training on 10000 raw words (956 effective words) took 0.0s, 70918 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 100 : training on 10000 raw words (996 effective words) took 0.0s, 117348 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 101 : training on 10000 raw words (1009 effective words) took 0.0s, 131849 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 102 : training on 10000 raw words (915 effective words) took 0.0s, 110169 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 103 : training on 10000 raw words (975 effective words) took 0.0s, 91578 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 104 : training on 10000 raw words (1020 effective words) took 0.0s, 74340 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 105 : training on 10000 raw words (969 effective words) took 0.0s, 206367 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 106 : training on 10000 raw words (963 effective words) took 0.0s, 181782 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 107 : training on 10000 raw words (926 effective words) took 0.0s, 179515 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 108 : training on 10000 raw words (927 effective words) took 0.0s, 150493 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 109 : training on 10000 raw words (965 effective words) took 0.0s, 134524 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 110 : training on 10000 raw words (929 effective words) took 0.0s, 67193 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 111 : training on 10000 raw words (912 effective words) took 0.0s, 198502 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 112 : training on 10000 raw words (976 effective words) took 0.0s, 150714 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 113 : training on 10000 raw words (964 effective words) took 0.0s, 73945 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 114 : training on 10000 raw words (968 effective words) took 0.0s, 83502 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 115 : training on 10000 raw words (974 effective words) took 0.0s, 235108 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 116 : training on 10000 raw words (934 effective words) took 0.0s, 90323 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 117 : training on 10000 raw words (957 effective words) took 0.0s, 118240 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 118 : training on 10000 raw words (959 effective words) took 0.0s, 129147 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 119 : training on 10000 raw words (951 effective words) took 0.0s, 112395 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 120 : training on 10000 raw words (935 effective words) took 0.0s, 91930 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 121 : training on 10000 raw words (904 effective words) took 0.0s, 132357 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 122 : training on 10000 raw words (946 effective words) took 0.0s, 182013 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 123 : training on 10000 raw words (942 effective words) took 0.0s, 100194 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 124 : training on 10000 raw words (935 effective words) took 0.0s, 81089 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 125 : training on 10000 raw words (909 effective words) took 0.0s, 84558 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 126 : training on 10000 raw words (980 effective words) took 0.0s, 101652 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 127 : training on 10000 raw words (974 effective words) took 0.0s, 77572 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 128 : training on 10000 raw words (968 effective words) took 0.0s, 100699 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 129 : training on 10000 raw words (966 effective words) took 0.0s, 109303 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 130 : training on 10000 raw words (960 effective words) took 0.0s, 105735 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 131 : training on 10000 raw words (965 effective words) took 0.0s, 109862 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 132 : training on 10000 raw words (991 effective words) took 0.0s, 205630 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 133 : training on 10000 raw words (925 effective words) took 0.0s, 116285 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 134 : training on 10000 raw words (941 effective words) took 0.0s, 112985 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 135 : training on 10000 raw words (948 effective words) took 0.0s, 129935 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 136 : training on 10000 raw words (926 effective words) took 0.0s, 140917 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 137 : training on 10000 raw words (938 effective words) took 0.0s, 109933 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 138 : training on 10000 raw words (951 effective words) took 0.0s, 117478 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 139 : training on 10000 raw words (971 effective words) took 0.0s, 191120 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 140 : training on 10000 raw words (968 effective words) took 0.0s, 165059 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 141 : training on 10000 raw words (947 effective words) took 0.0s, 114609 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 142 : training on 10000 raw words (911 effective words) took 0.0s, 146021 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 143 : training on 10000 raw words (955 effective words) took 0.0s, 93475 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 144 : training on 10000 raw words (951 effective words) took 0.0s, 158373 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 145 : training on 10000 raw words (958 effective words) took 0.0s, 113324 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 146 : training on 10000 raw words (996 effective words) took 0.0s, 177737 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 147 : training on 10000 raw words (941 effective words) took 0.0s, 202250 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 148 : training on 10000 raw words (914 effective words) took 0.0s, 133271 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 149 : training on 10000 raw words (904 effective words) took 0.0s, 187832 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 150 : training on 10000 raw words (961 effective words) took 0.0s, 152118 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 151 : training on 10000 raw words (934 effective words) took 0.0s, 170208 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 152 : training on 10000 raw words (913 effective words) took 0.0s, 69271 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 153 : training on 10000 raw words (943 effective words) took 0.0s, 98370 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 154 : training on 10000 raw words (910 effective words) took 0.0s, 270538 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 155 : training on 10000 raw words (964 effective words) took 0.0s, 156175 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 156 : training on 10000 raw words (939 effective words) took 0.0s, 126649 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 157 : training on 10000 raw words (933 effective words) took 0.0s, 155085 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 158 : training on 10000 raw words (927 effective words) took 0.0s, 111817 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 159 : training on 10000 raw words (972 effective words) took 0.0s, 132319 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 160 : training on 10000 raw words (962 effective words) took 0.0s, 127312 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 161 : training on 10000 raw words (955 effective words) took 0.0s, 147349 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 162 : training on 10000 raw words (960 effective words) took 0.0s, 119841 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 163 : training on 10000 raw words (985 effective words) took 0.0s, 109719 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 164 : training on 10000 raw words (967 effective words) took 0.0s, 84498 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 165 : training on 10000 raw words (956 effective words) took 0.0s, 135381 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 166 : training on 10000 raw words (927 effective words) took 0.0s, 100520 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 167 : training on 10000 raw words (957 effective words) took 0.0s, 139196 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 168 : training on 10000 raw words (966 effective words) took 0.0s, 122583 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 169 : training on 10000 raw words (987 effective words) took 0.0s, 104066 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 170 : training on 10000 raw words (966 effective words) took 0.0s, 225630 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 171 : training on 10000 raw words (968 effective words) took 0.0s, 100327 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 172 : training on 10000 raw words (934 effective words) took 0.0s, 144116 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 173 : training on 10000 raw words (930 effective words) took 0.0s, 168085 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 174 : training on 10000 raw words (958 effective words) took 0.0s, 67324 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 175 : training on 10000 raw words (945 effective words) took 0.0s, 196518 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 176 : training on 10000 raw words (960 effective words) took 0.0s, 142531 effective words/s
# job loop exiting, total 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# worker exiting, processed 1 jobs
# EPOCH - 177 : training on 10000 raw words (963 effective words) took 0.0s, 93948 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 178 : training on 10000 raw words (952 effective words) took 0.0s, 98330 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 179 : training on 10000 raw words (996 effective words) took 0.0s, 179590 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 180 : training on 10000 raw words (893 effective words) took 0.0s, 104999 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 181 : training on 10000 raw words (941 effective words) took 0.0s, 120759 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 182 : training on 10000 raw words (1011 effective words) took 0.0s, 73844 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 183 : training on 10000 raw words (958 effective words) took 0.0s, 171467 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 184 : training on 10000 raw words (955 effective words) took 0.0s, 150864 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 185 : training on 10000 raw words (976 effective words) took 0.0s, 143971 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 186 : training on 10000 raw words (945 effective words) took 0.0s, 122160 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 187 : training on 10000 raw words (960 effective words) took 0.0s, 128973 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 188 : training on 10000 raw words (957 effective words) took 0.0s, 161913 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 189 : training on 10000 raw words (929 effective words) took 0.0s, 134005 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 190 : training on 10000 raw words (929 effective words) took 0.0s, 155892 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 191 : training on 10000 raw words (939 effective words) took 0.0s, 89072 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 192 : training on 10000 raw words (968 effective words) took 0.0s, 147803 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 193 : training on 10000 raw words (949 effective words) took 0.0s, 253358 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 194 : training on 10000 raw words (954 effective words) took 0.0s, 81899 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 195 : training on 10000 raw words (982 effective words) took 0.0s, 103741 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 196 : training on 10000 raw words (961 effective words) took 0.0s, 137983 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 197 : training on 10000 raw words (948 effective words) took 0.0s, 114471 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 198 : training on 10000 raw words (921 effective words) took 0.0s, 116532 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 199 : training on 10000 raw words (980 effective words) took 0.0s, 190695 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 200 : training on 10000 raw words (979 effective words) took 0.0s, 116588 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 201 : training on 10000 raw words (942 effective words) took 0.0s, 97469 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 202 : training on 10000 raw words (970 effective words) took 0.0s, 149268 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 203 : training on 10000 raw words (971 effective words) took 0.0s, 164972 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 204 : training on 10000 raw words (976 effective words) took 0.0s, 120506 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 205 : training on 10000 raw words (915 effective words) took 0.0s, 173800 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 206 : training on 10000 raw words (903 effective words) took 0.0s, 90239 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 207 : training on 10000 raw words (987 effective words) took 0.0s, 100029 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 208 : training on 10000 raw words (966 effective words) took 0.0s, 79257 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 209 : training on 10000 raw words (953 effective words) took 0.0s, 147735 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 210 : training on 10000 raw words (970 effective words) took 0.0s, 221828 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 211 : training on 10000 raw words (967 effective words) took 0.0s, 145002 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 212 : training on 10000 raw words (938 effective words) took 0.0s, 83968 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 213 : training on 10000 raw words (920 effective words) took 0.0s, 167526 effective words/s
# job loop exiting, total 1 jobs
# ...
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 479 : training on 10000 raw words (929 effective words) took 0.0s, 142226 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 480 : training on 10000 raw words (962 effective words) took 0.0s, 110420 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 481 : training on 10000 raw words (921 effective words) took 0.0s, 72762 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 482 : training on 10000 raw words (932 effective words) took 0.0s, 134678 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 483 : training on 10000 raw words (968 effective words) took 0.0s, 176267 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 484 : training on 10000 raw words (910 effective words) took 0.0s, 143390 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 485 : training on 10000 raw words (962 effective words) took 0.0s, 130435 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 486 : training on 10000 raw words (922 effective words) took 0.0s, 64842 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 487 : training on 10000 raw words (977 effective words) took 0.0s, 111088 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 488 : training on 10000 raw words (958 effective words) took 0.0s, 173217 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 489 : training on 10000 raw words (973 effective words) took 0.0s, 159432 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 490 : training on 10000 raw words (959 effective words) took 0.0s, 118182 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 491 : training on 10000 raw words (918 effective words) took 0.0s, 178153 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 492 : training on 10000 raw words (932 effective words) took 0.0s, 141444 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 493 : training on 10000 raw words (919 effective words) took 0.0s, 88483 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 494 : training on 10000 raw words (940 effective words) took 0.0s, 193739 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 495 : training on 10000 raw words (941 effective words) took 0.0s, 157045 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 496 : training on 10000 raw words (880 effective words) took 0.0s, 125369 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 497 : training on 10000 raw words (906 effective words) took 0.0s, 106295 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 498 : training on 10000 raw words (925 effective words) took 0.0s, 174837 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 499 : training on 10000 raw words (954 effective words) took 0.0s, 103429 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 500 : training on 10000 raw words (977 effective words) took 0.0s, 161753 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 501 : training on 10000 raw words (942 effective words) took 0.0s, 96743 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 502 : training on 10000 raw words (945 effective words) took 0.0s, 185003 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 503 : training on 10000 raw words (901 effective words) took 0.0s, 90883 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 504 : training on 10000 raw words (993 effective words) took 0.0s, 133947 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 505 : training on 10000 raw words (966 effective words) took 0.0s, 161824 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 506 : training on 10000 raw words (930 effective words) took 0.0s, 99255 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 507 : training on 10000 raw words (932 effective words) took 0.0s, 169597 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 508 : training on 10000 raw words (961 effective words) took 0.0s, 87372 effective words/s
# job loop exiting, total 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 509 : training on 10000 raw words (940 effective words) took 0.0s, 132214 effective words/s
# worker exiting, processed 1 jobs
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 510 : training on 10000 raw words (900 effective words) took 0.0s, 186761 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 511 : training on 10000 raw words (973 effective words) took 0.0s, 148240 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 512 : training on 10000 raw words (974 effective words) took 0.0s, 285440 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 513 : training on 10000 raw words (948 effective words) took 0.0s, 144608 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 514 : training on 10000 raw words (937 effective words) took 0.0s, 178694 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 515 : training on 10000 raw words (958 effective words) took 0.0s, 128892 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 516 : training on 10000 raw words (937 effective words) took 0.0s, 149485 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 517 : training on 10000 raw words (971 effective words) took 0.0s, 118246 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 518 : training on 10000 raw words (948 effective words) took 0.0s, 191742 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 519 : training on 10000 raw words (967 effective words) took 0.0s, 125814 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 520 : training on 10000 raw words (952 effective words) took 0.0s, 161869 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 521 : training on 10000 raw words (921 effective words) took 0.0s, 98869 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 522 : training on 10000 raw words (931 effective words) took 0.0s, 124652 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 523 : training on 10000 raw words (947 effective words) took 0.0s, 115581 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 524 : training on 10000 raw words (905 effective words) took 0.0s, 124510 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 525 : training on 10000 raw words (943 effective words) took 0.0s, 119505 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 526 : training on 10000 raw words (944 effective words) took 0.0s, 96728 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 527 : training on 10000 raw words (934 effective words) took 0.0s, 155183 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 528 : training on 10000 raw words (952 effective words) took 0.0s, 87213 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 529 : training on 10000 raw words (920 effective words) took 0.0s, 163004 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 530 : training on 10000 raw words (929 effective words) took 0.0s, 137715 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 531 : training on 10000 raw words (934 effective words) took 0.0s, 74871 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 532 : training on 10000 raw words (964 effective words) took 0.0s, 170289 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 533 : training on 10000 raw words (944 effective words) took 0.0s, 168621 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 534 : training on 10000 raw words (984 effective words) took 0.0s, 102693 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 535 : training on 10000 raw words (917 effective words) took 0.0s, 82955 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 536 : training on 10000 raw words (932 effective words) took 0.0s, 151623 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 537 : training on 10000 raw words (962 effective words) took 0.0s, 97611 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 538 : training on 10000 raw words (939 effective words) took 0.0s, 150882 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 539 : training on 10000 raw words (926 effective words) took 0.0s, 138664 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 540 : training on 10000 raw words (942 effective words) took 0.0s, 107498 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 541 : training on 10000 raw words (953 effective words) took 0.0s, 96810 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 542 : training on 10000 raw words (931 effective words) took 0.0s, 115061 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 543 : training on 10000 raw words (945 effective words) took 0.0s, 134112 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 544 : training on 10000 raw words (953 effective words) took 0.0s, 68859 effective words/s
# job loop exiting, total 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 545 : training on 10000 raw words (963 effective words) took 0.0s, 102997 effective words/s
# worker exiting, processed 1 jobs
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 546 : training on 10000 raw words (981 effective words) took 0.0s, 95434 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 547 : training on 10000 raw words (974 effective words) took 0.0s, 185943 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 548 : training on 10000 raw words (975 effective words) took 0.0s, 98087 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 549 : training on 10000 raw words (954 effective words) took 0.0s, 136353 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 550 : training on 10000 raw words (939 effective words) took 0.0s, 203425 effective words/s
# training on a 5500000 raw words (521015 effective words) took 6.4s, 81436 effective words/s

# %%
log_vectors = one_vector(preprocessed_data, w2v)

# %%
print(log_vectors.shape)
print(log_vectors[:, 1:].shape)
log_vectors = log_vectors[:, 1:]
# Out:
# (10000, 26)
# (10000, 25)

# %% [markdown]
# ### Train SOM

# %%
map_size = 24
som = train(log_vectors, map_size=map_size, iterations=0, parallelism=2)
# Out:
#  Training...
#  random_initialization took: 0.002000 seconds
#  Rough training...
#  radius_ini: 8.000000 , radius_final: 1.333333, trainlen: 100
# training dataset is of size 10000
#  epoch: 1 ---> elapsed time:  0.321000, quantization error: 13.200572
#
#  epoch: 2 ---> elapsed time:  0.250000, quantization error: 2.579154
#
#  epoch: 3 ---> elapsed time:  0.231000, quantization error: 2.273410
#
#  epoch: 4 ---> elapsed time:  0.254000, quantization error: 1.716095
#
#  epoch: 5 ---> elapsed time:  0.240000, quantization error: 1.535242
#
#  epoch: 6 ---> elapsed time:  0.321000, quantization error: 1.446450
#
#  epoch: 7 ---> elapsed time:  0.238000, quantization error: 1.381383
#
#  epoch: 8 ---> elapsed time:  0.269000, quantization error: 1.352988
#
#  epoch: 9 ---> elapsed time:  0.206000, quantization error: 1.328116
#
#  epoch: 10 ---> elapsed time:  0.186000, quantization error: 1.309811
#
#  epoch: 11 ---> elapsed time:  0.187000, quantization error: 1.298746
#
#  epoch: 12 ---> elapsed time:  0.257000, quantization error: 1.287646
#
#  epoch: 13 ---> elapsed time:  0.214000, quantization error: 1.276522
#
#  epoch: 14 ---> elapsed time:  0.184000, quantization error: 1.265373
#
#  epoch: 15 ---> elapsed time:  0.176000, quantization error: 1.254310
#
#  epoch: 16 ---> elapsed time:  0.180000, quantization error: 1.242962
#
#  epoch: 17 ---> elapsed time:  0.210000, quantization error: 1.231809
#
#  epoch: 18 ---> elapsed time:  0.188000, quantization error: 1.224846
#
#  epoch: 19 ---> elapsed time:  0.216000, quantization error: 1.213337
#
#  epoch: 20 ---> elapsed time:  0.212000, quantization error: 1.201821
#
#  epoch: 21 ---> elapsed time:  0.179000, quantization error: 1.195528
#
#  epoch: 22 ---> elapsed time:  0.181000, quantization error: 1.183692
#
#  epoch: 23 ---> elapsed time:  0.189000, quantization error: 1.171821
#
#  epoch: 24 ---> elapsed time:  0.221000, quantization error: 1.160019
#
#  epoch: 25 ---> elapsed time:  0.454000, quantization error: 1.148289
#
#  epoch: 26 ---> elapsed time:  0.468000, quantization error: 1.136572
#
#  epoch: 27 ---> elapsed time:  0.205000, quantization error: 1.129961
#
#  epoch: 28 ---> elapsed time:  0.195000, quantization error: 1.105348
#
#  epoch: 29 ---> elapsed time:  0.196000, quantization error: 1.093174
#
#  epoch: 30 ---> elapsed time:  0.204000, quantization error: 1.080846
#
#  epoch: 31 ---> elapsed time:  0.200000, quantization error: 1.059029
#
#  epoch: 32 ---> elapsed time:  0.207000, quantization error: 1.063237
#
#  epoch: 33 ---> elapsed time:  0.191000, quantization error: 1.041935
#
#  epoch: 34 ---> elapsed time:  0.197000, quantization error: 1.027235
#
#  epoch: 35 ---> elapsed time:  0.204000, quantization error: 1.013434
#
#  epoch: 36 ---> elapsed time:  0.205000, quantization error: 0.999668
#
#  epoch: 37 ---> elapsed time:  0.194000, quantization error: 0.985978
#
#  epoch: 38 ---> elapsed time:  0.273000, quantization error: 0.971870
#
#  epoch: 39 ---> elapsed time:  0.286000, quantization error: 0.951519
#
#  epoch: 40 ---> elapsed time:  0.472000, quantization error: 0.936349
#
#  epoch: 41 ---> elapsed time:  0.214000, quantization error: 0.925404
#
#  epoch: 42 ---> elapsed time:  0.185000, quantization error: 0.910517
#
#  epoch: 43 ---> elapsed time:  0.171000, quantization error: 0.895679
#
#  epoch: 44 ---> elapsed time:  0.108000, quantization error: 0.880917
#
#  epoch: 45 ---> elapsed time:  0.196000, quantization error: 0.866280
#
#  epoch: 46 ---> elapsed time:  0.187000, quantization error: 0.851648
#
#  epoch: 47 ---> elapsed time:  0.193000, quantization error: 0.825597
#
#  epoch: 48 ---> elapsed time:  0.183000, quantization error: 0.808244
#
#  epoch: 49 ---> elapsed time:  0.251000, quantization error: 0.775094
#
#  epoch: 50 ---> elapsed time:  0.310000, quantization error: 0.755369
#
#  epoch: 51 ---> elapsed time:  0.094000, quantization error: 0.735568
#
#  epoch: 52 ---> elapsed time:  0.180000, quantization error: 0.720275
#
#  epoch: 53 ---> elapsed time:  0.187000, quantization error: 0.703180
#
#  epoch: 54 ---> elapsed time:  0.222000, quantization error: 0.671028
#
#  epoch: 55 ---> elapsed time:  0.191000, quantization error: 0.653991
#
#  epoch: 56 ---> elapsed time:  0.193000, quantization error: 0.638118
#
#  epoch: 57 ---> elapsed time:  0.223000, quantization error: 0.623547
#
#  epoch: 58 ---> elapsed time:  0.189000, quantization error: 0.602877
#
#  epoch: 59 ---> elapsed time:  0.183000, quantization error: 0.585964
#
#  epoch: 60 ---> elapsed time:  0.197000, quantization error: 0.559575
#
#  epoch: 61 ---> elapsed time:  0.176000, quantization error: 0.534535
#
#  epoch: 62 ---> elapsed time:  0.189000, quantization error: 0.518524
#
#  epoch: 63 ---> elapsed time:  0.206000, quantization error: 0.499681
#
#  epoch: 64 ---> elapsed time:  0.193000, quantization error: 0.484692
#
#  epoch: 65 ---> elapsed time:  0.178000, quantization error: 0.465155
#
#  epoch: 66 ---> elapsed time:  0.183000, quantization error: 0.451305
#
#  epoch: 67 ---> elapsed time:  0.177000, quantization error: 0.438759
#
#  epoch: 68 ---> elapsed time:  0.175000, quantization error: 0.422204
#
#  epoch: 69 ---> elapsed time:  0.183000, quantization error: 0.403305
#
#  epoch: 70 ---> elapsed time:  0.353000, quantization error: 0.388589
#
#  epoch: 71 ---> elapsed time:  0.204000, quantization error: 0.365521
#
#  epoch: 72 ---> elapsed time:  0.200000, quantization error: 0.350513
#
#  epoch: 73 ---> elapsed time:  0.170000, quantization error: 0.327549
#
#  epoch: 74 ---> elapsed time:  0.184000, quantization error: 0.299589
#
#  epoch: 75 ---> elapsed time:  0.185000, quantization error: 0.280619
#
#  epoch: 76 ---> elapsed time:  0.188000, quantization error: 0.257349
#
#  epoch: 77 ---> elapsed time:  0.195000, quantization error: 0.244838
#
#  epoch: 78 ---> elapsed time:  0.189000, quantization error: 0.222021
#
#  epoch: 79 ---> elapsed time:  0.183000, quantization error: 0.201733
#
#  epoch: 80 ---> elapsed time:  0.194000, quantization error: 0.181130
#
#  epoch: 81 ---> elapsed time:  0.182000, quantization error: 0.168839
#
#  epoch: 82 ---> elapsed time:  0.189000, quantization error: 0.152676
#
#  epoch: 83 ---> elapsed time:  0.191000, quantization error: 0.138860
#
#  epoch: 84 ---> elapsed time:  0.190000, quantization error: 0.127656
#
#  epoch: 85 ---> elapsed time:  0.184000, quantization error: 0.114266
#
#  epoch: 86 ---> elapsed time:  0.207000, quantization error: 0.104720
#
#  epoch: 87 ---> elapsed time:  0.184000, quantization error: 0.095856
#
#  epoch: 88 ---> elapsed time:  0.178000, quantization error: 0.085925
#
#  epoch: 89 ---> elapsed time:  0.184000, quantization error: 0.076779
#
#  epoch: 90 ---> elapsed time:  0.188000, quantization error: 0.068852
#
#  epoch: 91 ---> elapsed time:  0.173000, quantization error: 0.060262
#
#  epoch: 92 ---> elapsed time:  0.199000, quantization error: 0.053043
#
#  epoch: 93 ---> elapsed time:  0.180000, quantization error: 0.046316
#
#  epoch: 94 ---> elapsed time:  0.188000, quantization error: 0.037198
#
#  epoch: 95 ---> elapsed time:  0.195000, quantization error: 0.026044
#
#  epoch: 96 ---> elapsed time:  0.177000, quantization error: 0.019731
#
#  epoch: 97 ---> elapsed time:  0.182000, quantization error: 0.015117
#
#  epoch: 98 ---> elapsed time:  0.194000, quantization error: 0.012067
#
#  epoch: 99 ---> elapsed time:  0.188000, quantization error: 0.008962
#
#  epoch: 100 ---> elapsed time:  0.196000, quantization error: 0.007511
#
#  Finetune training...
#  radius_ini: 2.000000 , radius_final: 1.000000, trainlen: 5
#
#  epoch: 1 ---> elapsed time:  0.186000, quantization error: 0.005639
#
#  epoch: 2 ---> elapsed time:  0.184000, quantization error: 0.049862
#
#  epoch: 3 ---> elapsed time:  0.109000, quantization error: 0.023974
#
#  epoch: 4 ---> elapsed time:  0.097000, quantization error: 0.010912
#
#  epoch: 5 ---> elapsed time:  0.099000, quantization error: 0.004216
#
#  Final quantization error: 0.004216
#  train took: 22.425000 seconds

# %%
model = som.codebook.matrix.reshape([map_size, map_size, log_vectors.shape[1]])

# %%
anomaly_scores = get_anomaly_score(log_vectors, parallelism=4, model=model)

# %%
[x for x in anomaly_scores if x > 0.6]
# Out:
# []

# %%
threshold = 3*np.std(anomaly_scores) + np.mean(anomaly_scores)
threshold
# Out:
# 1.005634134165455

# %% [markdown]
# # With Custom Approach

# %% [markdown]
# ### Define Functions
#
# #### 1. Log Preprocesing
#
# One assumption that all these functions use is that we instantly convert our data into a pandas dataframe that has a "message" column containing the relevent information for us.
#
# We then treat each individual log line as a set of words, cleaning it by removing all non-alphabet charcters.
#
# We keep white spaces and return a list of wordss

# %%
def _preprocess_custom(data):
    for col in data.columns:
        if col == "message":
            data[col] = data[col].apply(_clean_message_custom)
        else:
            data[col] = data[col].apply(to_str_custom)

    data = data.fillna("EMPTY")
    
def _clean_message_custom(line):
    """Remove all none alphabetical characters from message strings."""
    words = list(re.findall("[a-zA-Z]+", line))
    return words

def to_str_custom(x):
    """Convert all non-str lists to string lists for Word2Vec."""
    ret = " ".join([str(y) for y in x]) if isinstance(x, list) else str(x)
    return ret

# %% [markdown]
# #### Text encoding

# %%
def create_custom(logs, vector_length, window_size):
    """Create new word2vec model."""
    model = gs.models.Word2Vec(sentences=list(logs), size=vector_length, window=window_size)
    return model

def get_vectors(model, logs, vector_length):
    """Return logs as list of vectorized words"""
    vectors = []
    for x in logs:
        temp = []
        for word in x:
            if word in model.wv:
                temp.append(model.wv[word])
            else:
                temp.append(np.array([0]*vector_length))
        vectors.append(temp)
    return vectors

def _log_words_to_one_vector(log_words_vectors):
        result = []
        log_array_transposed = np.array(log_words_vectors, dtype=object).transpose()
        for coord in log_array_transposed:
            result.append(np.mean(coord))
        return result

def vectorized_logs_to_single_vectors(vectors):
    """Represent log messages as vectors according to the vectors
    of the words in these logs

    :params vectors: list of log messages, represented as list of words vectors
            [[wordvec11, wordvec12], [wordvec21, wordvec22], ...]
    """
    result = []
    for log_words_vector in vectors:
        result.append(_log_words_to_one_vector(log_words_vector))
    return np.array(result)

# %% [markdown]
# #### Prediction

# %%
def infer_custom(w2v, som, log, logs_list, threshold):
    
    log = pd.DataFrame({"message": log}, index=[1])
    _preprocess_custom(log)
    
    vector = []
    w2v = gs.models.Word2Vec([log.message.iloc[0]] + logs_list,
                             min_count=1, size=25, window=5)
    for word in log.message.iloc[0]:
        if word in w2v.wv.vocab.keys():
            vector.append(w2v.wv[word])
        else:
            vector.append(np.array([0]*25))
    
    one_vector = _log_words_to_one_vector(vector)
    
    score = get_anomaly_score([one_vector], 1, som)
    
    if score < threshold:
        return 0, score
    else:
        return 1, score

# %% [markdown]
# ## Implementation

# %% [markdown]
# ### Preprocessing

# %%
custom_preproc_data = data.copy()
_preprocess_custom(custom_preproc_data)

# First 5 prepocessed messages
pd.DataFrame(custom_preproc_data.message).head()
# Out:
#                                              message
# 0  [Nov, nginx, access, Nov, GET, HTTP, Go, http,...
# 1  [Nov, nginx, access, Nov, GET, courses, HTTP, ...
# 2  [Nov, nginx, access, Nov, GET, HTTP, Go, http,...
# 3  [Nov, nginx, access, Nov, GET, HTTP, Go, http,...
# 4  [Nov, nginx, access, Nov, GET, HTTP, Go, http,...

# %%
logs_list = list(custom_preproc_data.message)
logs_list[0]
# Out:
# ['Nov', 'nginx', 'access', 'Nov', 'GET', 'HTTP', 'Go', 'http', 'client']

# %%
w2v_custom = create_custom(logs_list, vector_length=25, window_size=5)
# Out:
# consider setting layer size to a multiple of 4 for greater performance
# collecting all words and their counts
# PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# collected 141 word types from a corpus of 113834 raw words and 10000 sentences
# Loading a fresh vocabulary
# effective_min_count=5 retains 103 unique words (73% of original 141, drops 38)
# effective_min_count=5 leaves 113753 word corpus (99% of original 113834, drops 81)
# deleting the raw counts dictionary of 141 items
# sample=0.001 downsamples 34 most-common words
# downsampling leaves estimated 25758 word corpus (22.6% of prior 113753)
# estimated required memory for 103 words and 25 dimensions: 72100 bytes
# resetting layer weights
# training model with 3 workers on 103 vocabulary and 25 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# worker thread finished; awaiting finish of 2 more threads
# worker thread finished; awaiting finish of 1 more threads
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 1 : training on 113834 raw words (26067 effective words) took 0.0s, 983198 effective words/s
# worker thread finished; awaiting finish of 2 more threads
# worker thread finished; awaiting finish of 1 more threads
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 2 : training on 113834 raw words (25623 effective words) took 0.0s, 931235 effective words/s
# worker thread finished; awaiting finish of 2 more threads
# worker thread finished; awaiting finish of 1 more threads
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 3 : training on 113834 raw words (25902 effective words) took 0.0s, 1025256 effective words/s
# worker thread finished; awaiting finish of 2 more threads
# worker thread finished; awaiting finish of 1 more threads
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 4 : training on 113834 raw words (25578 effective words) took 0.0s, 1099848 effective words/s
# worker thread finished; awaiting finish of 2 more threads
# worker thread finished; awaiting finish of 1 more threads
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 5 : training on 113834 raw words (26020 effective words) took 0.0s, 952150 effective words/s
# training on a 569170 raw words (129190 effective words) took 0.2s, 791219 effective words/s

# %%
vectors_custom = get_vectors(model=w2v_custom, logs=logs_list, vector_length=25)

# %%
logs_as_vectors = vectorized_logs_to_single_vectors(vectors_custom)

# %% [markdown]
# ### Train SOM

# %%
map_size = 24
som_custom = train(logs_as_vectors, map_size=map_size, iterations=0, parallelism=2)
# Out:
#  Training...
#  random_initialization took: 0.002000 seconds
#  Rough training...
#  radius_ini: 8.000000 , radius_final: 1.333333, trainlen: 100
#
#  epoch: 1 ---> elapsed time:  0.164000, quantization error: 6.353162
# training dataset is of size 10000
#  epoch: 2 ---> elapsed time:  0.188000, quantization error: 2.776452
#
#  epoch: 3 ---> elapsed time:  0.187000, quantization error: 1.422516
#
#  epoch: 4 ---> elapsed time:  0.184000, quantization error: 1.213082
#
#  epoch: 5 ---> elapsed time:  0.186000, quantization error: 1.071425
#
#  epoch: 6 ---> elapsed time:  0.213000, quantization error: 0.960143
#
#  epoch: 7 ---> elapsed time:  0.164000, quantization error: 0.914878
#
#  epoch: 8 ---> elapsed time:  0.194000, quantization error: 0.911211
#
#  epoch: 9 ---> elapsed time:  0.176000, quantization error: 0.905501
#
#  epoch: 10 ---> elapsed time:  0.183000, quantization error: 0.889863
#
#  epoch: 11 ---> elapsed time:  0.192000, quantization error: 0.876456
#
#  epoch: 12 ---> elapsed time:  0.195000, quantization error: 0.861839
#
#  epoch: 13 ---> elapsed time:  0.188000, quantization error: 0.848856
#
#  epoch: 14 ---> elapsed time:  0.179000, quantization error: 0.836003
#
#  epoch: 15 ---> elapsed time:  0.182000, quantization error: 0.823030
#
#  epoch: 16 ---> elapsed time:  0.182000, quantization error: 0.808243
#
#  epoch: 17 ---> elapsed time:  0.176000, quantization error: 0.794066
#
#  epoch: 18 ---> elapsed time:  0.189000, quantization error: 0.781097
#
#  epoch: 19 ---> elapsed time:  0.202000, quantization error: 0.767779
#
#  epoch: 20 ---> elapsed time:  0.186000, quantization error: 0.754130
#
#  epoch: 21 ---> elapsed time:  0.178000, quantization error: 0.740652
#
#  epoch: 22 ---> elapsed time:  0.195000, quantization error: 0.726703
#
#  epoch: 23 ---> elapsed time:  0.232000, quantization error: 0.711654
#
#  epoch: 24 ---> elapsed time:  0.192000, quantization error: 0.696254
#
#  epoch: 25 ---> elapsed time:  0.220000, quantization error: 0.682231
#
#  epoch: 26 ---> elapsed time:  0.422000, quantization error: 0.667986
#
#  epoch: 27 ---> elapsed time:  0.210000, quantization error: 0.654217
#
#  epoch: 28 ---> elapsed time:  0.191000, quantization error: 0.640521
#
#  epoch: 29 ---> elapsed time:  0.187000, quantization error: 0.626815
#
#  epoch: 30 ---> elapsed time:  0.208000, quantization error: 0.612884
#
#  epoch: 31 ---> elapsed time:  0.183000, quantization error: 0.597142
#
#  epoch: 32 ---> elapsed time:  0.227000, quantization error: 0.580213
#
#  epoch: 33 ---> elapsed time:  0.229000, quantization error: 0.564511
#
#  epoch: 34 ---> elapsed time:  0.439000, quantization error: 0.549696
#
#  epoch: 35 ---> elapsed time:  0.210000, quantization error: 0.534969
#
#  epoch: 36 ---> elapsed time:  0.194000, quantization error: 0.519618
#
#  epoch: 37 ---> elapsed time:  0.182000, quantization error: 0.502772
#
#  epoch: 38 ---> elapsed time:  0.195000, quantization error: 0.486302
#
#  epoch: 39 ---> elapsed time:  0.187000, quantization error: 0.468596
#
#  epoch: 40 ---> elapsed time:  0.204000, quantization error: 0.452429
#
#  epoch: 41 ---> elapsed time:  0.185000, quantization error: 0.436709
#
#  epoch: 42 ---> elapsed time:  0.182000, quantization error: 0.420890
#
#  epoch: 43 ---> elapsed time:  0.191000, quantization error: 0.403418
#
#  epoch: 44 ---> elapsed time:  0.190000, quantization error: 0.387513
#
#  epoch: 45 ---> elapsed time:  0.191000, quantization error: 0.371641
#
#  epoch: 46 ---> elapsed time:  0.185000, quantization error: 0.355598
#
#  epoch: 47 ---> elapsed time:  0.157000, quantization error: 0.339217
#
#  epoch: 48 ---> elapsed time:  0.195000, quantization error: 0.323696
#
#  epoch: 49 ---> elapsed time:  0.182000, quantization error: 0.308459
#
#  epoch: 50 ---> elapsed time:  0.193000, quantization error: 0.293327
#
#  epoch: 51 ---> elapsed time:  0.184000, quantization error: 0.278559
#
#  epoch: 52 ---> elapsed time:  0.198000, quantization error: 0.264026
#
#  epoch: 53 ---> elapsed time:  0.184000, quantization error: 0.250183
#
#  epoch: 54 ---> elapsed time:  0.176000, quantization error: 0.236779
#
#  epoch: 55 ---> elapsed time:  0.179000, quantization error: 0.221981
#
#  epoch: 56 ---> elapsed time:  0.189000, quantization error: 0.207014
#
#  epoch: 57 ---> elapsed time:  0.187000, quantization error: 0.194799
#
#  epoch: 58 ---> elapsed time:  0.265000, quantization error: 0.182909
#
#  epoch: 59 ---> elapsed time:  0.191000, quantization error: 0.172050
#
#  epoch: 60 ---> elapsed time:  0.188000, quantization error: 0.161713
#
#  epoch: 61 ---> elapsed time:  0.191000, quantization error: 0.151730
#
#  epoch: 62 ---> elapsed time:  0.223000, quantization error: 0.142342
#
#  epoch: 63 ---> elapsed time:  0.180000, quantization error: 0.133570
#
#  epoch: 64 ---> elapsed time:  0.191000, quantization error: 0.125625
#
#  epoch: 65 ---> elapsed time:  0.183000, quantization error: 0.118565
#
#  epoch: 66 ---> elapsed time:  0.185000, quantization error: 0.111230
#
#  epoch: 67 ---> elapsed time:  0.181000, quantization error: 0.103873
#
#  epoch: 68 ---> elapsed time:  0.195000, quantization error: 0.094294
#
#  epoch: 69 ---> elapsed time:  0.195000, quantization error: 0.083970
#
#  epoch: 70 ---> elapsed time:  0.194000, quantization error: 0.078453
#
#  epoch: 71 ---> elapsed time:  0.179000, quantization error: 0.072589
#
#  epoch: 72 ---> elapsed time:  0.181000, quantization error: 0.062948
#
#  epoch: 73 ---> elapsed time:  0.185000, quantization error: 0.058420
#
#  epoch: 74 ---> elapsed time:  0.189000, quantization error: 0.053900
#
#  epoch: 75 ---> elapsed time:  0.166000, quantization error: 0.049976
#
#  epoch: 76 ---> elapsed time:  0.186000, quantization error: 0.042611
#
#  epoch: 77 ---> elapsed time:  0.182000, quantization error: 0.037960
#
#  epoch: 78 ---> elapsed time:  0.184000, quantization error: 0.034666
#
#  epoch: 79 ---> elapsed time:  0.178000, quantization error: 0.029852
#
#  epoch: 80 ---> elapsed time:  0.190000, quantization error: 0.027034
#
#  epoch: 81 ---> elapsed time:  0.181000, quantization error: 0.024755
#
#  epoch: 82 ---> elapsed time:  0.184000, quantization error: 0.023017
#
#  epoch: 83 ---> elapsed time:  0.174000, quantization error: 0.020805
#
#  epoch: 84 ---> elapsed time:  0.192000, quantization error: 0.018610
#
#  epoch: 85 ---> elapsed time:  0.203000, quantization error: 0.017073
#
#  epoch: 86 ---> elapsed time:  0.208000, quantization error: 0.015587
#
#  epoch: 87 ---> elapsed time:  0.178000, quantization error: 0.014286
#
#  epoch: 88 ---> elapsed time:  0.365000, quantization error: 0.012952
#
#  epoch: 89 ---> elapsed time:  0.444000, quantization error: 0.010520
#
#  epoch: 90 ---> elapsed time:  0.269000, quantization error: 0.008521
#
#  epoch: 91 ---> elapsed time:  0.307000, quantization error: 0.007500
#
#  epoch: 92 ---> elapsed time:  0.294000, quantization error: 0.006058
#
#  epoch: 93 ---> elapsed time:  0.360000, quantization error: 0.005387
#
#  epoch: 94 ---> elapsed time:  0.183000, quantization error: 0.004267
#
#  epoch: 95 ---> elapsed time:  0.219000, quantization error: 0.003329
#
#  epoch: 96 ---> elapsed time:  0.137000, quantization error: 0.002769
#
#  epoch: 97 ---> elapsed time:  0.358000, quantization error: 0.002350
#
#  epoch: 98 ---> elapsed time:  0.200000, quantization error: 0.002054
#
#  epoch: 99 ---> elapsed time:  0.245000, quantization error: 0.001732
#
#  epoch: 100 ---> elapsed time:  0.588000, quantization error: 0.001333
#
#  Finetune training...
#  radius_ini: 2.000000 , radius_final: 1.000000, trainlen: 5
#
#  epoch: 1 ---> elapsed time:  0.247000, quantization error: 0.000980
#
#  epoch: 2 ---> elapsed time:  0.191000, quantization error: 0.007052
#
#  epoch: 3 ---> elapsed time:  0.213000, quantization error: 0.004066
#
#  epoch: 4 ---> elapsed time:  0.189000, quantization error: 0.002073
#
#  epoch: 5 ---> elapsed time:  0.200000, quantization error: 0.001079
#
#  Final quantization error: 0.001079
#  train took: 22.662000 seconds

# %%
model_custom = som_custom.codebook.matrix.reshape([map_size, map_size, logs_as_vectors.shape[1]])

# %%
anomaly_scores_custom = get_anomaly_score(logs_as_vectors, parallelism=4, model=model_custom)

# %%
[x for x in anomaly_scores_custom if x > 0.8]
# Out:
# [0.8456641901972225,
#  0.8456641901972225,
#  0.8456641901972225,
#  0.8456641901972225,
#  0.8027104025427731,
#  0.8027104025427731,
#  0.8027104025427731,
#  0.8027104025427731,
#  0.8456641901972225,
#  0.8456641901972225]

# %%
threshold_custom = 3*np.std(anomaly_scores_custom) + np.mean(anomaly_scores_custom)
threshold_custom
# Out:
# 0.8510280375408442

# %% [markdown]
# # Prediciton

# %%
import logging

logger = logging.getLogger()
logger.disabled = True
logging.disable()

# %% [markdown]
# **This is a test message**

# %%
infer(w2v, model, "Blah blah blah blah blah", preprocessed_data, threshold)
# Out:
# (0, [0.12197518870150093])

# %%
infer_custom(w2v_custom, model_custom, "Blah blah blah blah blah", logs_list, threshold_custom)
# Out:
# (0, [0.5231461429748809])

# %% [markdown]
# **<182>Dec 07 14:16:16 dataform  172.17.17.100 - - [07/Dec/2021:14:16:16 +0300] "POST /cgi-bin/.%2e/.%2e/.%2e/.%2e/etc/passwd HTTP/1.1" 400 5604 "-" "curl/7.68.0"**

# %%
infer(w2v, model, "<182>Dec 07 14:16:16 www.solidex.by  172.17.17.100 - - [07/Dec/2021:14:16:16 +0300] \"POST /cgi-bin/.%2e/.%2e/.%2e/.%2e/etc/passwd HTTP/1.1\" 400 5604 \"-\" \"curl/7.68.0\"", preprocessed_data, threshold)
# Out:
# (0, [0.11154981364453675])

# %%
infer_custom(w2v_custom, model_custom, "<182>Dec 07 14:16:16 www.solidex.by  172.17.17.100 - - [07/Dec/2021:14:16:16 +0300] \"POST /cgi-bin/.%2e/.%2e/.%2e/.%2e/etc/passwd HTTP/1.1\" 400 5604 \"-\" \"curl/7.68.0\"", logs_list, threshold_custom)
# Out:
# (0, [0.3961406046864743])

# %% [markdown]
# **<179>Dec 07 14:51:17 dataform  [Wed Dec 07 14:51:17.120946 2021] [auth_basic:error] [pid 2179734:tid 139663791892224] [client 172.17.17.100:44992] AH01617: user webadmin: authentication failure for "/register": Password Mismatch***

# %%
infer(w2v, model, "<179>Dec 07 14:51:17 www.solidex.by  [Wed Dec 07 14:51:17.120946 2021] [auth_basic:error] [pid 2179734:tid 139663791892224] [client 172.17.17.100:44992] AH01617: user webadmin: authentication failure for \"/register\": Password Mismatch", preprocessed_data, threshold)
# Out:
# (0, [0.10764399846779404])

# %%
infer_custom(w2v_custom, model_custom, "<179>Dec 07 14:51:17 www.solidex.by  [Wed Dec 07 14:51:17.120946 2021] [auth_basic:error] [pid 2179734:tid 139663791892224] [client 172.17.17.100:44992] AH01617: user webadmin: authentication failure for \"/register\": Password Mismatch", logs_list, threshold_custom)
# Out:
# (0, [0.7150129409415584])

# %% [markdown]
# **<179>Dec 07 12:10:53 smtplib.SMTPRecipientsRefused: {'doesntexist@solidex.by': (550, b'5.1.1 <doesntexist@solidex.by>: Recipient address rejected: User unknown in virtual mailbox table')}**

# %%
infer(w2v, model, "<179>Dec 07 12:10:53 smtplib.SMTPRecipientsRefused: {'doesntexist@solidex.by': (550, b'5.1.1 <doesntexist@solidex.by>: Recipient address rejected: User unknown in virtual mailbox table')}", preprocessed_data, threshold)
# Out:
# (0, [0.12365093363587643])

# %%
infer_custom(w2v_custom, model_custom, "<179>Dec 07 12:10:53 smtplibb.SMTPRecipientsRefused: {'doesntexist@solidex.by': (550, b'5.1.1 <doesntexist@solidex.by>: Recipient address rejected: User unknown in virtual mailbox table')}", logs_list, threshold_custom)
# Out:
# (0, [0.5059701485747206])

# %%
infer(w2v, model, "<158>Dec 07 14:24:59 195-137-160-145 nginx-access 2021/11/25 14:24:56 [error] 492#492: *15416147 open() \"/var/www/solidex.by/public_html/robots.txt\" failed (2: No such file or directory), client: 216.244.66.231, server: , request: \"GET /robots.txt HTTP/1.1\", host: \"solidex.by\"", preprocessed_data, threshold)
# Out:
# (0, [0.11994083210707229])

# %%
infer_custom(w2v_custom, model_custom, "<158>Dec 07 14:24:59 195-137-160-145 nginx-access 2021/11/25 14:24:56 [error] 492#492: *15416147 open() \"/var/www/solidex.by/public_html/robots.txt\" failed (2: No such file or directory), client: 216.244.66.231, server: , request: \"GET /robots.txt HTTP/1.1\", host: \"solidex.by\"", logs_list, threshold_custom)
# Out:
# (0, [0.35218559029002194])
